# %%
data = [
    ['name','age','city'],
    ['helen','30','miami'],
    ['allen','36','sandigo']
]

with open('people.csv',mode='w',newline='') as file:
  writer = csv.writer(file)
  writer.writerows(data)

# %%
with open('people.csv',mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age', 'city']
# ['helen', '30', 'miami']
# ['allen', '36', 'sandigo']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import os

# %%
image_directory = '/content/drive/MyDrive/dataset/Healthy/'
os.chdir(image_directory)

# %%
image_files = [f for f in os.listdir(image_directory) if os.path.isfile(f)]
print(image_files)
# Out:
# ['s14-Pz-206.jpg', 's14-Pz-205.jpg', 's14-Pz-204.jpg', 's14-Pz-207.jpg', 's14-Pz-209.jpg', 's14-Pz-208.jpg', 'h13-Cz-55.jpg', 'h13-Cz-58.jpg', 'h13-Cz-57.jpg', 'h13-Cz-56.jpg', 'h13-Cz-59.jpg', 'h13-Cz-60.jpg', 'h13-Cz-61.jpg', 'h13-Cz-62.jpg', 'h13-Cz-63.jpg', 'h13-Cz-66.jpg', 'h13-Cz-64.jpg', 'h13-Cz-65.jpg', 'h13-Cz-67.jpg', 'h13-Cz-68.jpg', 'h13-Cz-69.jpg', 'h13-Cz-71.jpg', 'h13-Cz-70.jpg', 'h13-Cz-73.jpg', 'h13-Cz-72.jpg', 'h13-Cz-74.jpg', 'h13-Cz-76.jpg', 'h13-Cz-75.jpg', 'h13-Cz-78.jpg', 'h13-Cz-79.jpg', 'h13-Cz-77.jpg', 'h13-Cz-80.jpg', 'h13-Cz-81.jpg', 'h13-Cz-82.jpg', 'h13-Cz-83.jpg', 'h13-Cz-84.jpg', 'h13-Cz-86.jpg', 'h13-Cz-87.jpg', 'h13-Cz-85.jpg', 'h13-Cz-89.jpg', 'h13-Cz-90.jpg', 'h13-Cz-88.jpg', 'h13-Cz-93.jpg', 'h13-Cz-92.jpg', 'h13-Cz-91.jpg', 'h13-Cz-94.jpg', 'h13-Cz-95.jpg', 'h13-Cz-96.jpg', 'h13-Cz-97.jpg', 'h13-Cz-99.jpg', 'h13-Cz-98.jpg', 'h13-Cz-100.jpg', 'h13-Cz-101.jpg', 'h13-Cz-103.jpg', 'h13-Cz-104.jpg', 'h13-Cz-102.jpg', 'h13-Cz-106.jpg', 'h13-Cz-107.jpg', 'h13-Cz-105.jpg', 'h13-Cz-110.jpg', 'h13-Cz-109.jpg', 'h13-Cz-108.jpg', 'h13-Cz-113.jpg', 'h13-Cz-112.jpg', 'h13-Cz-111.jpg', 'h13-Cz-114.jpg', 'h13-Cz-115.jpg', 'h13-Cz-116.jpg', 'h13-Cz-117.jpg', 'h13-Cz-119.jpg', 'h13-Cz-118.jpg', 'h13-Cz-121.jpg', 'h13-Cz-120.jpg', 'h13-Cz-122.jpg', 'h13-Cz-124.jpg', 'h13-Cz-123.jpg', 'h13-Cz-127.jpg', 'h13-Cz-126.jpg', 'h13-Cz-125.jpg', 'h13-Cz-130.jpg', 'h13-Cz-128.jpg', 'h13-Cz-129.jpg', 'h13-Cz-131.jpg', 'h13-Cz-132.jpg', 'h13-Cz-134.jpg', 'h13-Cz-133.jpg', 'h13-Cz-135.jpg', 'h13-Cz-137.jpg', 'h13-Cz-136.jpg', 'h13-Cz-138.jpg', 'h13-Cz-139.jpg', 'h13-Cz-140.jpg', 'h13-Cz-143.jpg', 'h13-Cz-141.jpg', 'h13-Cz-142.jpg', 'h13-Cz-144.jpg', 'h13-Cz-145.jpg', 'h13-Cz-146.jpg', 'h13-Cz-147.jpg', 'h13-Cz-149.jpg', 'h13-Cz-148.jpg', 'h13-Cz-150.jpg', 'h13-Cz-151.jpg', 'h13-Cz-152.jpg', 'h13-Cz-155.jpg', 'h13-Cz-154.jpg', 'h13-Cz-153.jpg', 'h13-Cz-156.jpg', 'h13-Cz-157.jpg', 'h13-Cz-158.jpg', 'h13-Cz-160.jpg', 'h13-Cz-159.jpg', 'h13-Cz-163.jpg', 'h13-Cz-162.jpg', 'h13-Cz-161.jpg', 'h13-Cz-164.jpg', 'h13-Cz-166.jpg', 'h13-Cz-165.jpg', 'h13-Cz-168.jpg', 'h13-Cz-167.jpg', 'h13-Cz-171.jpg', 'h13-Cz-169.jpg', 'h13-Cz-170.jpg', 'h13-Cz-174.jpg', 'h13-Cz-173.jpg', 'h13-Cz-172.jpg', 'h13-Cz-177.jpg', 'h13-Cz-175.jpg', 'h13-Cz-176.jpg', 'h13-Cz-180.jpg', 'h13-Cz-179.jpg', 'h13-Cz-178.jpg', 'h13-Cz-182.jpg', 'h13-Cz-181.jpg', 'h13-Cz-183.jpg', 'h13-Cz-185.jpg', 'h13-Cz-184.jpg', 'h13-Cz-186.jpg', 'h13-Cz-187.jpg', 'h13-Cz-188.jpg', 'h13-Cz-190.jpg', 'h13-Cz-189.jpg', 'h13-Cz-192.jpg', 'h13-Cz-194.jpg', 'h13-Cz-193.jpg', 'h13-Cz-191.jpg', 'h13-Cz-196.jpg', 'h13-Cz-197.jpg', 'h13-Cz-195.jpg', 'h13-Cz-200.jpg', 'h13-Cz-198.jpg', 'h13-Cz-199.jpg', 'h13-Cz-202.jpg', 'h13-Cz-201.jpg', 'h13-Cz-203.jpg', 'h13-Cz-204.jpg', 'h13-Cz-206.jpg', 'h13-Cz-205.jpg', 'h13-Cz-207.jpg', 'h13-Cz-208.jpg', 'h13-Cz-209.jpg', 'h13-Pz-0.jpg', 'h13-Cz-210.jpg', 'h13-Pz-1.jpg', 'h13-Pz-4.jpg', 'h13-Pz-2.jpg', 'h13-Pz-3.jpg', 'h13-Pz-7.jpg', 'h13-Pz-6.jpg', 'h13-Pz-5.jpg', 'h13-Pz-8.jpg', 'h13-Pz-9.jpg', 'h13-Pz-10.jpg', 'h13-Pz-12.jpg', 'h13-Pz-11.jpg', 'h13-Pz-15.jpg', 'h13-Pz-13.jpg', 'h13-Pz-14.jpg', 'h13-Pz-16.jpg', 'h13-Pz-18.jpg', 'h13-Pz-17.jpg', 'h13-Pz-20.jpg', 'h13-Pz-21.jpg', 'h13-Pz-19.jpg', 'h13-Pz-22.jpg', 'h13-Pz-23.jpg', 'h13-Pz-24.jpg', 'h13-Pz-25.jpg', 'h13-Pz-26.jpg', 'h13-Pz-29.jpg', 'h13-Pz-28.jpg', 'h13-Pz-27.jpg', 'h13-Pz-30.jpg', 'h13-Pz-32.jpg', 'h13-Pz-31.jpg', 'h13-Pz-35.jpg', 'h13-Pz-34.jpg', 'h13-Pz-33.jpg', 'h13-Pz-36.jpg', 'h13-Pz-37.jpg', 'h13-Pz-39.jpg', 'h13-Pz-40.jpg', 'h13-Pz-38.jpg', 'h13-Pz-43.jpg', 'h13-Pz-42.jpg', 'h13-Pz-41.jpg', 'h13-Pz-44.jpg', 'h13-Pz-45.jpg', 'h13-Pz-48.jpg', 'h13-Pz-47.jpg', 'h13-Pz-46.jpg', 'h13-Pz-50.jpg', 'h13-Pz-49.jpg', 'h13-Pz-51.jpg', 'h13-Pz-54.jpg', 'h13-Pz-52.jpg', 'h13-Pz-53.jpg', 'h13-Pz-55.jpg', 'h13-Pz-56.jpg', 'h13-Pz-57.jpg', 'h13-Pz-60.jpg', 'h13-Pz-59.jpg', 'h13-Pz-58.jpg', 'h13-Pz-61.jpg', 'h13-Pz-62.jpg', 'h13-Pz-63.jpg', 'h13-Pz-64.jpg', 'h13-Pz-65.jpg', 'h13-Pz-66.jpg', ...

# %%
def FindLabel(filename):
  first_letter = filename[0]

  if first_letter.lower() == 's':
    return 'Sz'
  elif first_letter.lower() == 'h':
    return 'Health'
  else:
    return None

# %%
image_data = [(filename, FindLabel(filename)) for filename in image_files]

# %%
with open('data_labels.csv',mode='w',newline='') as file:
  writer = csv.writer(file)
  writer.writerow(['image_name','label'])
  writer.writerows(image_data)

# %%
with open('data_labels.csv',mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['h10-Fz-87.jpg', 'Health']
# ['h10-Fz-88.jpg', 'Health']
# ['h10-Fz-89.jpg', 'Health']
# ['h10-Fz-90.jpg', 'Health']
# ['h10-Fz-91.jpg', 'Health']
# ['h10-Fz-93.jpg', 'Health']
# ['h10-Fz-92.jpg', 'Health']
# ['h10-Fz-94.jpg', 'Health']
# ['h10-Fz-96.jpg', 'Health']
# ['h10-Fz-95.jpg', 'Health']
# ['h10-Fz-97.jpg', 'Health']
# ['h10-Fz-98.jpg', 'Health']
# ['h10-Fz-99.jpg', 'Health']
# ['h10-Fz-100.jpg', 'Health']
# ['h10-Fz-102.jpg', 'Health']
# ['h10-Fz-101.jpg', 'Health']
# ['h10-Fz-105.jpg', 'Health']
# ['h10-Fz-104.jpg', 'Health']
# ['h10-Fz-103.jpg', 'Health']
# ['h10-Fz-106.jpg', 'Health']
# ['h10-Fz-108.jpg', 'Health']
# ['h10-Fz-109.jpg', 'Health']
# ['h10-Fz-107.jpg', 'Health']
# ['h10-Fz-110.jpg', 'Health']
# ['h10-Fz-111.jpg', 'Health']
# ['h10-Fz-114.jpg', 'Health']
# ['h10-Fz-113.jpg', 'Health']
# ['h10-Fz-112.jpg', 'Health']
# ['h10-Fz-117.jpg', 'Health']
# ['h10-Fz-115.jpg', 'Health']
# ['h10-Fz-116.jpg', 'Health']
# ['h10-Fz-119.jpg', 'Health']
# ['h10-Fz-118.jpg', 'Health']
# ['h10-Fz-120.jpg', 'Health']
# ['h10-Fz-123.jpg', 'Health']
# ['h10-Fz-121.jpg', 'Health']
# ['h10-Fz-122.jpg', 'Health']
# ['h10-Fz-124.jpg', 'Health']
# ['h10-Fz-126.jpg', 'Health']
# ['h10-Fz-125.jpg', 'Health']
# ['h10-Fz-129.jpg', 'Health']
# ['h10-Fz-127.jpg', 'Health']
# ['h10-Fz-128.jpg', 'Health']
# ['h10-Fz-131.jpg', 'Health']
# ['h10-Fz-130.jpg', 'Health']
# ['h10-Fz-133.jpg', 'Health']
# ['h10-Fz-132.jpg', 'Health']
# ['h10-Fz-134.jpg', 'Health']
# ['h10-Fz-135.jpg', 'Health']
# ['h10-Fz-136.jpg', 'Health']
# ['h10-Fz-137.jpg', 'Health']
# ['h10-Fz-138.jpg', 'Health']
# ['h10-Fz-139.jpg', 'Health']
# ['h10-Fz-140.jpg', 'Health']
# ['h10-Fz-141.jpg', 'Health']
# ['h10-Fz-142.jpg', 'Health']
# ['h10-Fz-143.jpg', 'Health']
# ['h10-Fz-146.jpg', 'Health']
# ['h10-Fz-144.jpg', 'Health']
# ['h10-Fz-145.jpg', 'Health']
# ['h10-Fz-147.jpg', 'Health']
# ['h10-Fz-149.jpg', 'Health']
# ['h10-Fz-148.jpg', 'Health']
# ['h10-Fz-152.jpg', 'Health']
# ['h10-Fz-150.jpg', 'Health']
# ['h10-Fz-151.jpg', 'Health']
# ['h10-Fz-156.jpg', 'Health']
# ['h10-Fz-154.jpg', 'Health']
# ['h10-Fz-155.jpg', 'Health']
# ['h10-Fz-153.jpg', 'Health']
# ['h10-Fz-157.jpg', 'Health']
# ['h10-Fz-158.jpg', 'Health']
# ['h10-Fz-160.jpg', 'Health']
# ['h10-Fz-162.jpg', 'Health']
# ['h10-Fz-159.jpg', 'Health']
# ['h10-Fz-161.jpg', 'Health']
# ['h10-Fz-165.jpg', 'Health']
# ['h10-Fz-164.jpg', 'Health']
# ['h10-Fz-163.jpg', 'Health']
# ['h10-Fz-167.jpg', 'Health']
# ['h10-Fz-168.jpg', 'Health']
# ['h10-Fz-166.jpg', 'Health']
# ['h10-Fz-170.jpg', 'Health']
# ['h10-Fz-169.jpg', 'Health']
# ['h10-Fz-173.jpg', 'Health']
# ['h10-Fz-172.jpg', 'Health']
# ['h10-Fz-171.jpg', 'Health']
# ['h10-Fz-175.jpg', 'Health']
# ['h10-Fz-176.jpg', 'Health']
# ['h10-Fz-174.jpg', 'Health']
# ['h10-Fz-177.jpg', 'Health']
# ['h10-Fz-178.jpg', 'Health']
# ['h10-Fz-181.jpg', 'Health']
# ['h10-Fz-179.jpg', 'Health']
# ['h10-Fz-180.jpg', 'Health']
# ['h10-Fz-184.jpg', 'Health']
# ['h10-Fz-183.jpg', 'Health']
# ['h10-Fz-182.jpg', 'Health']
# ['h10-Fz-187.jpg', 'Health']
# ['h10-Fz-185.jpg', 'Health']
# ['h10-Fz-186.jpg', 'Health']
# ['h10-Fz-190.jpg', 'Health']
# ['h10-Fz-189.jpg', 'Health']
# ['h10-Fz-188.jpg', 'Health']
# ['h10-Fz-193.jpg', 'Health']
# ['h10-Fz-192.jpg', 'Health']
# ['h10-Fz-191.jpg', 'Health']
# ['h10-Fz-194.jpg', 'Health']
# ['h07-Fz-94.jpg', 'Health']
# ['h07-Fz-96.jpg', 'Health']
# ['h07-Fz-97.jpg', 'Health']
# ['h07-Fz-95.jpg', 'Health']
# ['h07-Fz-100.jpg', 'Health']
# ['h07-Fz-98.jpg', 'Health']
# ['h07-Fz-99.jpg', 'Health']
# ['h07-Fz-101.jpg', 'Health']
# ['h07-Fz-103.jpg', 'Health']
# ['h07-Fz-102.jpg', 'Health']
# ['h07-Fz-105.jpg', 'Health']
# ['h07-Fz-106.jpg', 'Health']
# ['h07-Fz-104.jpg', 'Health']
# ['h07-Fz-109.jpg', 'Health']
# ['h07-Fz-107.jpg', 'Health']
# ['h07-Fz-108.jpg', 'Health']
# ['h07-Fz-112.jpg', 'Health']
# ['h07-Fz-111.jpg', 'Health']
# ['h07-Fz-110.jpg', 'Health']
# ['h07-Fz-113.jpg', 'Health']
# ['h07-Fz-114.jpg', 'Health']
# ['h07-Fz-115.jpg', 'Health']
# ['h07-Fz-116.jpg', 'Health']
# ['h07-Fz-117.jpg', 'Health']
# ['h07-Fz-118.jpg', 'Health']
# ['h07-Fz-119.jpg', 'Health']
# ['h07-Fz-120.jpg', 'Health']
# ['h07-Fz-123.jpg', 'Health']
# ['h07-Fz-121.jpg', 'Health']
# ['h07-Fz-122.jpg', 'Health']
# ['h07-Fz-125.jpg', 'Health']
# ['h07-Fz-126.jpg', 'Health']
# ['h07-Fz-124.jpg', 'Health']
# ['h07-Fz-128.jpg', 'Health']
# ['h07-Fz-127.jpg', 'Health']
# ['h07-Fz-129.jpg', 'Health']
# ['h07-Fz-130.jpg', 'Health']
# ['h07-Fz-131.jpg', 'Health']
# ['h07-Fz-132.jpg', 'Health']
# ['h07-Fz-133.jpg', 'Health']
# ['h07-Fz-134.jpg', 'Health']
# ['h07-Fz-135.jpg', 'Health']
# ['h07-Fz-138.jpg', 'Health']
# ['h07-Fz-137.jpg', 'Health']
# ['h07-Fz-136.jpg', 'Health']
# ['h07-Fz-140.jpg', 'Health']
# ['h07-Fz-139.jpg', 'Health']
# ['h07-Fz-141.jpg', 'Health']
# ['h07-Fz-144.jpg', 'Health']
# ['h07-Fz-142.jpg', 'Health']
# ['h07-Fz-143.jpg', 'Health']
# ['h07-Fz-146.jpg', 'Health']
# ['h07-Fz-145.jpg', 'Health']
# ['h07-Fz-148.jpg', 'Health']
# ['h07-Fz-149.jpg', 'Health']
# ['h07-Fz-147.jpg', 'Health']
# ['h07-Fz-151.jpg', 'Health']
# ['h07-Fz-150.jpg', 'Health']
# ['h07-Fz-152.jpg', 'Health']
# ['h07-Fz-155.jpg', 'Health']
# ['h07-Fz-153.jpg', 'Health']
# ['h07-Fz-154.jpg', 'Health']
# ['h07-Fz-157.jpg', 'Health']
# ['h07-Fz-156.jpg', 'Health']
# ['h07-Fz-158.jpg', 'Health']
# ['h07-Fz-161.jpg', 'Health']
# ['h07-Fz-160.jpg', 'Health']
# ['h07-Fz-159.jpg', 'Health']
# ['h07-Fz-163.jpg', 'Health']
# ['h07-Fz-164.jpg', 'Health']
# ['h07-Fz-162.jpg', 'Health']
# ['h07-Fz-165.jpg', 'Health']
# ['h07-Fz-167.jpg', 'Health']
# ['h07-Fz-166.jpg', 'Health']
# ['h07-Fz-170.jpg', 'Health']
# ['h07-Fz-168.jpg', 'Health']
# ['h07-Fz-169.jpg', 'Health']
# ['h07-Fz-171.jpg', 'Health']
# ['h07-Fz-173.jpg', 'Health']
# ['h07-Fz-172.jpg', 'Health']
# ['h07-Fz-175.jpg', 'Health']
# ['h07-Fz-176.jpg', 'Health']
# ['h07-Fz-174.jpg', 'Health']
# ['h07-Fz-178.jpg', 'Health']
# ['h07-Fz-177.jpg', 'Health']
# ['h07-Fz-179.jpg', 'Health']
# ['h07-Fz-181.jpg', 'Health']
# ['h07-Fz-180.jpg', 'Health']
# ['h07-Fz-183.jpg', 'Health']
# ['h07-Fz-182.jpg', 'Health']
# ['h07-Fz-184.jpg', 'Health']
# ['h07-Fz-188.jpg', 'Health']
# ['h07-Fz-185.jpg', 'Health']
# ['h07-Fz-187.jpg', 'Health']
# ['h07-Fz-186.jpg', 'Health']
# ['h07-Fz-191.jpg', 'Health']
# ['h07-Fz-189.jpg', 'Health']
# ['h07-Fz-190.jpg', 'Health']
# ['h07-Fz-193.jpg', 'Health']
# ['h07-Fz-192.jpg', 'Health']
# ['h07-Fz-197.jpg', 'Health']
# ['h07-Fz-196.jpg', 'Health']
# ['h07-Fz-195.jpg', 'Health']
# ['h07-Fz-194.jpg', 'Health']
# ['h07-Fz-200.jpg', 'Health']
# ['h07-Fz-198.jpg', 'Health']
# ['h07-Fz-199.jpg', 'Health']
# ['h07-Fz-201.jpg', 'Health']
# ['h07-Fz-202.jpg', 'Health']
# ['h07-Fz-203.jpg', 'Health']
# ['h07-Fz-205.jpg', 'Health']
# ['h07-Fz-204.jpg', 'Health']
# ['h07-Fz-206.jpg', 'Health']
# ['h07-Fz-207.jpg', 'Health']
# ['h07-Fz-208.jpg', 'Health']
# ['h07-Fz-209.jpg', 'Health']
# ['h07-Cz-0.jpg', 'Health']
# ['h07-Fz-210.jpg', 'Health']
# ['h07-Cz-1.jpg', 'Health']
# ['h07-Cz-4.jpg', 'Health']
# ['h07-Cz-3.jpg', 'Health']
# ['h07-Cz-2.jpg', 'Health']
# ['h07-Cz-6.jpg', 'Health']
# ['h07-Cz-5.jpg', 'Health']
# ['h07-Cz-9.jpg', 'Health']
# ['h07-Cz-7.jpg', 'Health']
# ['h07-Cz-8.jpg', 'Health']
# ['h07-Cz-12.jpg', 'Health']
# ['h07-Cz-13.jpg', 'Health']
# ['h07-Cz-11.jpg', 'Health']
# ['h07-Cz-10.jpg', 'Health']
# ['h07-Cz-15.jpg', 'Health']
# ['h07-Cz-14.jpg', 'Health']
# ['h07-Cz-18.jpg', 'Health']
# ['h07-Cz-17.jpg', 'Health']
# ['h07-Cz-16.jpg', 'Health']
# ['h07-Cz-21.jpg', 'Health']
# ['h07-Cz-19.jpg', 'Health']
# ['h07-Cz-20.jpg', 'Health']
# ['h07-Cz-22.jpg', 'Health']
# ['h07-Cz-23.jpg', 'Health']
# ['h07-Cz-25.jpg', 'Health']
# ['h07-Cz-24.jpg', 'Health']
# ['h07-Cz-26.jpg', 'Health']
# ['h07-Cz-27.jpg', 'Health']
# ['h07-Cz-29.jpg', 'Health']
# ['h07-Cz-28.jpg', 'Health']
# ['h07-Cz-32.jpg', 'Health']
# ['h07-Cz-30.jpg', 'Health']
# ['h07-Cz-31.jpg', 'Health']
# ['h07-Cz-35.jpg', 'Health']
# ['h07-Cz-34.jpg', 'Health']
# ['h07-Cz-33.jpg', 'Health']
# ['h07-Cz-37.jpg', 'Health']
# ['h07-Cz-38.jpg', 'Health']
# ['h07-Cz-36.jpg', 'Health']
# ['h07-Cz-39.jpg', 'Health']
# ['h07-Cz-40.jpg', 'Health']
# ['h07-Cz-42.jpg', 'Health']
# ['h07-Cz-41.jpg', 'Health']
# ['h07-Cz-43.jpg', 'Health']
# ['h07-Cz-44.jpg', 'Health']
# ['h07-Cz-47.jpg', 'Health']
# ['h07-Cz-46.jpg', 'Health']
# ['h07-Cz-45.jpg', 'Health']
# ['h07-Cz-49.jpg', 'Health']
# ['h07-Cz-48.jpg', 'Health']
# ['h07-Cz-50.jpg', 'Health']
# ['h07-Cz-52.jpg', 'Health']
# ['h07-Cz-51.jpg', 'Health']
# ['h07-Cz-53.jpg', 'Health']
# ['h07-Cz-55.jpg', 'Health']
# ['h07-Cz-56.jpg', 'Health']
# ['h07-Cz-54.jpg', 'Health']
# ['h07-Cz-58.jpg', 'Health']
# ['h07-Cz-57.jpg', 'Health']
# ['h07-Cz-59.jpg', 'Health']
# ['h07-Cz-61.jpg', 'Health']
# ['h07-Cz-62.jpg', 'Health']
# ['h07-Cz-60.jpg', 'Health']
# ['h07-Cz-63.jpg', 'Health']
# ['h07-Cz-64.jpg', 'Health']
# ['h07-Cz-66.jpg', 'Health']
# ['h07-Cz-65.jpg', 'Health']
# ['h07-Cz-67.jpg', 'Health']
# ['h07-Cz-70.jpg', 'Health']
# ['h07-Cz-69.jpg', 'Health']
# ['h07-Cz-68.jpg', 'Health']
# ['h07-Cz-74.jpg', 'Health']
# ['h07-Cz-71.jpg', 'Health']
# ['h07-Cz-72.jpg', 'Health']
# ['h07-Cz-73.jpg', 'Health']
# ['h07-Cz-76.jpg', 'Health']
# ['h07-Cz-75.jpg', 'Health']
# ['h07-Cz-77.jpg', 'Health']
# ['h07-Cz-78.jpg', 'Health']
# ['h07-Cz-79.jpg', 'Health']
# ['h07-Cz-82.jpg', 'Health']
# ['h07-Cz-83.jpg', 'Health']
# ['h07-Cz-81.jpg', 'Health']
# ['h07-Cz-80.jpg', 'Health']
# ['h07-Cz-85.jpg', 'Health']
# ['h07-Cz-86.jpg', 'Health']
# ['h07-Cz-84.jpg', 'Health']
# ['h07-Cz-89.jpg', 'Health']
# ['h07-Cz-88.jpg', 'Health']
# ['h07-Cz-87.jpg', 'Health']
# ['h07-Cz-91.jpg', 'Health']
# ['h07-Cz-90.jpg', 'Health']
# ['h07-Cz-92.jpg', 'Health']
# ['h07-Cz-93.jpg', 'Health']
# ['h07-Cz-94.jpg', 'Health']
# ['h07-Cz-98.jpg', 'Health']
# ['h07-Cz-96.jpg', 'Health']
# ['h07-Cz-97.jpg', 'Health']
# ['h07-Cz-95.jpg', 'Health']
# ['h07-Cz-99.jpg', 'Health']
# ['h07-Cz-100.jpg', 'Health']
# ['h07-Cz-101.jpg', 'Health']
# ['h07-Cz-102.jpg', 'Health']
# ['h07-Cz-103.jpg', 'Health']
# ['h07-Cz-106.jpg', 'Health']
# ['h07-Cz-104.jpg', 'Health']
# ['h07-Cz-105.jpg', 'Health']
# ['h07-Cz-110.jpg', 'Health']
# ['h07-Cz-107.jpg', 'Health']
# ['h07-Cz-109.jpg', 'Health']
# ['h07-Cz-108.jpg', 'Health']
# ['h07-Cz-111.jpg', 'Health']
# ['h07-Cz-113.jpg', 'Health']
# ['h07-Cz-112.jpg', 'Health']
# ['h07-Cz-114.jpg', 'Health']
# ['h07-Cz-115.jpg', 'Health']
# ['h07-Cz-116.jpg', 'Health']
# ['h07-Cz-117.jpg', 'Health']
# ['h07-Cz-118.jpg', 'Health']
# ['h07-Cz-119.jpg', 'Health']
# ['h07-Cz-120.jpg', 'Health']
# ['h07-Cz-121.jpg', 'Health']
# ['h07-Cz-124.jpg', 'Health']
# ['h07-Cz-123.jpg', 'Health']
# ['h07-Cz-122.jpg', 'Health']
# ['h07-Cz-126.jpg', 'Health']
# ['h07-Cz-125.jpg', 'Health']
# ['h07-Cz-127.jpg', 'Health']
# ['h07-Cz-130.jpg', 'Health']
# ['h07-Cz-128.jpg', 'Health']
# ['h07-Cz-129.jpg', 'Health']
# ['h07-Cz-131.jpg', 'Health']
# ['h07-Cz-132.jpg', 'Health']
# ['h07-Cz-133.jpg', 'Health']
# ['h07-Cz-134.jpg', 'Health']
# ['h07-Cz-135.jpg', 'Health']
# ['h07-Cz-136.jpg', 'Health']
# ['h07-Cz-138.jpg', 'Health']
# ['h07-Cz-137.jpg', 'Health']
# ['h07-Cz-140.jpg', 'Health']
# ['h07-Cz-139.jpg', 'Health']
# ['h07-Cz-141.jpg', 'Health']
# ['h07-Cz-143.jpg', 'Health']
# ['h07-Cz-142.jpg', 'Health']
# ['h07-Cz-144.jpg', 'Health']
# ['h07-Cz-145.jpg', 'Health']
# ['h07-Cz-147.jpg', 'Health']
# ['h07-Cz-146.jpg', 'Health']
# ['h07-Cz-149.jpg', 'Health']
# ['h07-Cz-148.jpg', 'Health']
# ['h07-Cz-151.jpg', 'Health']
# ['h07-Cz-150.jpg', 'Health']
# ['h07-Cz-152.jpg', 'Health']
# ['h07-Cz-154.jpg', 'Health']
# ['h07-Cz-155.jpg', 'Health']
# ['h07-Cz-153.jpg', 'Health']
# ['h07-Cz-158.jpg', 'Health']
# ['h07-Cz-156.jpg', 'Health']
# ['h07-Cz-157.jpg', 'Health']
# ['h07-Cz-161.jpg', 'Health']
# ['h07-Cz-159.jpg', 'Health']
# ['h07-Cz-160.jpg', 'Health']
# ['h07-Cz-164.jpg', 'Health']
# ['h07-Cz-163.jpg', 'Health']
# ['h07-Cz-162.jpg', 'Health']
# ['h07-Cz-167.jpg', 'Health']
# ['h07-Cz-166.jpg', 'Health']
# ['h07-Cz-165.jpg', 'Health']
# ['h07-Cz-170.jpg', 'Health']
# ['h07-Cz-168.jpg', 'Health']
# ['h07-Cz-169.jpg', 'Health']
# ['h07-Cz-172.jpg', 'Health']
# ['h07-Cz-173.jpg', 'Health']
# ['h07-Cz-171.jpg', 'Health']
# ['h07-Cz-176.jpg', 'Health']
# ['h07-Cz-174.jpg', 'Health']
# ['h07-Cz-175.jpg', 'Health']
# ['h07-Cz-178.jpg', 'Health']
# ['h07-Cz-179.jpg', 'Health']
# ['h07-Cz-177.jpg', 'Health']
# ['h07-Cz-180.jpg', 'Health']
# ['h07-Cz-182.jpg', 'Health']
# ['h07-Cz-181.jpg', 'Health']
# ['h07-Cz-185.jpg', 'Health']
# ['h07-Cz-184.jpg', 'Health']
# ['h07-Cz-183.jpg', 'Health']
# ['h07-Cz-188.jpg', 'Health']
# ['h07-Cz-187.jpg', 'Health']
# ['h07-Cz-186.jpg', 'Health']
# ['h07-Cz-190.jpg', 'Health']
# ['h07-Cz-189.jpg', 'Health']
# ['h07-Cz-191.jpg', 'Health']
# ['h07-Cz-193.jpg', 'Health']
# ['h07-Cz-194.jpg', 'Health']
# ['h07-Cz-192.jpg', 'Health']
# ['h07-Cz-195.jpg', 'Health']
# ['h07-Cz-197.jpg', 'Health']
# ['h07-Cz-196.jpg', 'Health']
# ['h07-Cz-198.jpg', 'Health']
# ['h07-Cz-199.jpg', 'Health']
# ['h07-Cz-200.jpg', 'Health']
# ['h07-Cz-201.jpg', 'Health']
# ['h07-Cz-203.jpg', 'Health']
# ['h07-Cz-202.jpg', 'Health']
# ['h07-Cz-206.jpg', 'Health']
# ['h07-Cz-204.jpg', 'Health']
# ['h07-Cz-205.jpg', 'Health']
# ['h07-Cz-209.jpg', 'Health']
# ['h07-Cz-207.jpg', 'Health']
# ['h07-Cz-208.jpg', 'Health']
# ['h07-Pz-0.jpg', 'Health']
# ['h07-Cz-210.jpg', 'Health']
# ['h07-Pz-1.jpg', 'Health']
# ['h07-Pz-4.jpg', 'Health']
# ['h07-Pz-2.jpg', 'Health']
# ['h07-Pz-3.jpg', 'Health']
# ['h07-Pz-5.jpg', 'Health']
# ['h07-Pz-6.jpg', 'Health']
# ['h07-Pz-9.jpg', 'Health']
# ['h07-Pz-8.jpg', 'Health']
# ['h07-Pz-7.jpg', 'Health']
# ['h07-Pz-10.jpg', 'Health']
# ['h07-Pz-12.jpg', 'Health']
# ['h07-Pz-11.jpg', 'Health']
# ['h07-Pz-15.jpg', 'Health']
# ['h07-Pz-13.jpg', 'Health']
# ['h07-Pz-14.jpg', 'Health']
# ['h07-Pz-16.jpg', 'Health']
# ['h07-Pz-18.jpg', 'Health']
# ['h07-Pz-17.jpg', 'Health']
# ['h07-Pz-19.jpg', 'Health']
# ['h07-Pz-20.jpg', 'Health']
# ['h07-Pz-21.jpg', 'Health']
# ['h07-Pz-23.jpg', 'Health']
# ['h07-Pz-22.jpg', 'Health']
# ['h07-Pz-24.jpg', 'Health']
# ['h07-Pz-25.jpg', 'Health']
# ['h07-Pz-26.jpg', 'Health']
# ['h07-Pz-27.jpg', 'Health']
# ['h07-Pz-28.jpg', 'Health']
# ['h07-Pz-31.jpg', 'Health']
# ['h07-Pz-30.jpg', 'Health']
# ['h07-Pz-29.jpg', 'Health']
# ['h07-Pz-33.jpg', 'Health']
# ['h07-Pz-34.jpg', 'Health']
# ['h07-Pz-32.jpg', 'Health']
# ['h07-Pz-36.jpg', 'Health']
# ['h07-Pz-35.jpg', 'Health']
# ['h07-Pz-37.jpg', 'Health']
# ['h07-Pz-38.jpg', 'Health']
# ['h07-Pz-39.jpg', 'Health']
# ['h07-Pz-40.jpg', 'Health']
# ['h07-Pz-41.jpg', 'Health']
# ['h07-Pz-42.jpg', 'Health']
# ['h07-Pz-43.jpg', 'Health']
# ['h07-Pz-45.jpg', 'Health']
# ['h07-Pz-46.jpg', 'Health']
# ['h07-Pz-44.jpg', 'Health']
# ['h07-Pz-47.jpg', 'Health']
# ['h07-Pz-48.jpg', 'Health']
# ['h07-Pz-49.jpg', 'Health']
# ['h07-Pz-50.jpg', 'Health']
# ['h07-Pz-51.jpg', 'Health']
# ['h07-Pz-52.jpg', 'Health']
# ['h07-Pz-55.jpg', 'Health']
# ['h07-Pz-53.jpg', 'Health']
# ['h07-Pz-54.jpg', 'Health']
# ['h07-Pz-57.jpg', 'Health']
# ['h07-Pz-58.jpg', 'Health']
# ['h07-Pz-56.jpg', 'Health']
# ['h07-Pz-59.jpg', 'Health']
# ['h07-Pz-61.jpg', 'Health']
# ['h07-Pz-60.jpg', 'Health']
# ['h07-Pz-63.jpg', 'Health']
# ['h07-Pz-64.jpg', 'Health']
# ['h07-Pz-62.jpg', 'Health']
# ['h07-Pz-67.jpg', 'Health']
# ['h07-Pz-65.jpg', 'Health']
# ['h07-Pz-66.jpg', 'Health']
# ['h07-Pz-68.jpg', 'Health']
# ['h07-Pz-70.jpg', 'Health']
# ['h07-Pz-71.jpg', 'Health']
# ['h07-Pz-69.jpg', 'Health']
# ['h07-Pz-72.jpg', 'Health']
# ['h07-Pz-74.jpg', 'Health']
# ['h07-Pz-73.jpg', 'Health']
# ['h07-Pz-76.jpg', 'Health']
# ['h07-Pz-75.jpg', 'Health']
# ['h07-Pz-77.jpg', 'Health']
# ['h07-Pz-78.jpg', 'Health']
# ['h07-Pz-79.jpg', 'Health']
# ['h07-Pz-81.jpg', 'Health']
# ['h07-Pz-80.jpg', 'Health']
# ['h07-Pz-83.jpg', 'Health']
# ['h07-Pz-82.jpg', 'Health']
# ['h07-Pz-84.jpg', 'Health']
# ['h07-Pz-85.jpg', 'Health']
# ['h07-Pz-86.jpg', 'Health']
# ['h07-Pz-89.jpg', 'Health']
# ['h07-Pz-87.jpg', 'Health']
# ['h07-Pz-88.jpg', 'Health']
# ['h07-Pz-90.jpg', 'Health']
# ['h07-Pz-91.jpg', 'Health']
# ['h07-Pz-93.jpg', 'Health']
# ['h07-Pz-92.jpg', 'Health']
# ['h07-Pz-95.jpg', 'Health']
# ['h07-Pz-94.jpg', 'Health']
# ['h07-Pz-97.jpg', 'Health']
# ['h07-Pz-96.jpg', 'Health']
# ['h07-Pz-100.jpg', 'Health']
# ['h07-Pz-98.jpg', 'Health']
# ['h07-Pz-99.jpg', 'Health']
# ['h07-Pz-101.jpg', 'Health']
# ['h07-Pz-102.jpg', 'Health']
# ['h07-Pz-103.jpg', 'Health']
# ['h07-Pz-105.jpg', 'Health']
# ['h07-Pz-106.jpg', 'Health']
# ['h07-Pz-104.jpg', 'Health']
# ['h07-Pz-108.jpg', 'Health']
# ['h07-Pz-107.jpg', 'Health']
# ['h07-Pz-109.jpg', 'Health']
# ['h07-Pz-111.jpg', 'Health']
# ['h07-Pz-112.jpg', 'Health']
# ['h07-Pz-110.jpg', 'Health']
# ['h07-Pz-113.jpg', 'Health']
# ['h07-Pz-115.jpg', 'Health']
# ['h07-Pz-114.jpg', 'Health']
# ['h07-Pz-116.jpg', 'Health']
# ['h07-Pz-117.jpg', 'Health']
# ['h07-Pz-118.jpg', 'Health']
# ['h07-Pz-120.jpg', 'Health']
# ['h07-Pz-119.jpg', 'Health']
# ['h07-Pz-122.jpg', 'Health']
# ['h07-Pz-123.jpg', 'Health']
# ['h07-Pz-121.jpg', 'Health']
# ['h07-Pz-126.jpg', 'Health']
# ['h07-Pz-125.jpg', 'Health']
# ['h07-Pz-124.jpg', 'Health']
# ['h07-Pz-128.jpg', 'Health']
# ['h07-Pz-127.jpg', 'Health']
# ['h07-Pz-131.jpg', 'Health']
# ['h07-Pz-130.jpg', 'Health']
# ['h07-Pz-129.jpg', 'Health']
# ['h07-Pz-134.jpg', 'Health']
# ['h07-Pz-132.jpg', 'Health']
# ['h07-Pz-133.jpg', 'Health']
# ['h07-Pz-137.jpg', 'Health']
# ['h07-Pz-135.jpg', 'Health']
# ['h07-Pz-136.jpg', 'Health']
# ['h07-Pz-139.jpg', 'Health']
# ['h07-Pz-138.jpg', 'Health']
# ['h07-Pz-140.jpg', 'Health']
# ['h07-Pz-141.jpg', 'Health']
# ['h07-Pz-143.jpg', 'Health']
# ['h07-Pz-142.jpg', 'Health']
# ['h07-Pz-146.jpg', 'Health']
# ['h07-Pz-144.jpg', 'Health']
# ['h07-Pz-145.jpg', 'Health']
# ['h07-Pz-149.jpg', 'Health']
# ['h07-Pz-148.jpg', 'Health']
# ['h07-Pz-147.jpg', 'Health']
# ['h07-Pz-150.jpg', 'Health']
# ['h07-Pz-152.jpg', 'Health']
# ['h07-Pz-151.jpg', 'Health']
# ['h07-Pz-154.jpg', 'Health']
# ['h07-Pz-155.jpg', 'Health']
# ['h07-Pz-153.jpg', 'Health']
# ['h07-Pz-156.jpg', 'Health']
# ['h07-Pz-157.jpg', 'Health']
# ['h07-Pz-158.jpg', 'Health']
# ['h07-Pz-161.jpg', 'Health']
# ['h07-Pz-159.jpg', 'Health']
# ['h07-Pz-160.jpg', 'Health']
# ['h07-Pz-162.jpg', 'Health']
# ['h07-Pz-164.jpg', 'Health']
# ['h07-Pz-163.jpg', 'Health']
# ['h07-Pz-165.jpg', 'Health']
# ['h07-Pz-166.jpg', 'Health']
# ['h07-Pz-167.jpg', 'Health']
# ['h07-Pz-170.jpg', 'Health']
# ['h07-Pz-168.jpg', 'Health']
# ['h07-Pz-169.jpg', 'Health']
# ['h07-Pz-172.jpg', 'Health']
# ['h07-Pz-171.jpg', 'Health']
# ['h07-Pz-173.jpg', 'Health']
# ['h07-Pz-174.jpg', 'Health']
# ['h07-Pz-176.jpg', 'Health']
# ['h07-Pz-175.jpg', 'Health']
# ['h07-Pz-179.jpg', 'Health']
# ['h07-Pz-177.jpg', 'Health']
# ['h07-Pz-178.jpg', 'Health']
# ['h07-Pz-181.jpg', 'Health']
# ['h07-Pz-180.jpg', 'Health']
# ['h07-Pz-182.jpg', 'Health']
# ['h07-Pz-185.jpg', 'Health']
# ['h07-Pz-183.jpg', 'Health']
# ['h07-Pz-184.jpg', 'Health']
# ['h07-Pz-188.jpg', 'Health']
# ['h07-Pz-186.jpg', 'Health']
# ['h07-Pz-187.jpg', 'Health']
# ['h07-Pz-190.jpg', 'Health']
# ['h07-Pz-189.jpg', 'Health']
# ['h07-Pz-191.jpg', 'Health']
# ['h07-Pz-193.jpg', 'Health']
# ['h07-Pz-194.jpg', 'Health']
# ['h07-Pz-192.jpg', 'Health']
# ['h07-Pz-195.jpg', 'Health']
# ['h07-Pz-196.jpg', 'Health']
# ['h07-Pz-197.jpg', 'Health']
# ['h07-Pz-200.jpg', 'Health']
# ['h07-Pz-199.jpg', 'Health']
# ['h07-Pz-198.jpg', 'Health']
# ['h07-Pz-203.jpg', 'Health']
# ['h07-Pz-202.jpg', 'Health']
# ['h07-Pz-201.jpg', 'Health']
# ['h07-Pz-205.jpg', 'Health']
# ['h07-Pz-206.jpg', 'Health']
# ['h07-Pz-204.jpg', 'Health']
# ['h07-Pz-208.jpg', 'Health']
# ['h07-Pz-207.jpg', 'Health']
# ['h07-Pz-209.jpg', 'Health']
# ['h07-Pz-210.jpg', 'Health']
# ['h08-Fz-0.jpg', 'Health']
# ['h08-Fz-3.jpg', 'Health']
# ['h08-Fz-1.jpg', 'Health']
# ['h08-Fz-2.jpg', 'Health']
# ['h08-Fz-4.jpg', 'Health']
# ['h08-Fz-5.jpg', 'Health']
# ['h08-Fz-8.jpg', 'Health']
# ['h08-Fz-6.jpg', 'Health']
# ['h08-Fz-7.jpg', 'Health']
# ['h08-Fz-11.jpg', 'Health']
# ['h08-Fz-9.jpg', 'Health']
# ['h08-Fz-10.jpg', 'Health']
# ['h08-Fz-14.jpg', 'Health']
# ['h08-Fz-12.jpg', 'Health']
# ['h08-Fz-13.jpg', 'Health']
# ['h08-Fz-15.jpg', 'Health']
# ['h08-Fz-16.jpg', 'Health']
# ['h08-Fz-17.jpg', 'Health']
# ['h08-Fz-19.jpg', 'Health']
# ['h08-Fz-18.jpg', 'Health']
# ['h08-Fz-20.jpg', 'Health']
# ['h08-Fz-22.jpg', 'Health']
# ['h08-Fz-23.jpg', 'Health']
# ['h08-Fz-21.jpg', 'Health']
# ['h08-Fz-26.jpg', 'Health']
# ['h08-Fz-25.jpg', 'Health']
# ['h08-Fz-24.jpg', 'Health']
# ['h08-Fz-28.jpg', 'Health']
# ['h08-Fz-29.jpg', 'Health']
# ['h08-Fz-27.jpg', 'Health']
# ['h08-Fz-31.jpg', 'Health']
# ['h08-Fz-32.jpg', 'Health']
# ['h08-Fz-30.jpg', 'Health']
# ['h08-Fz-34.jpg', 'Health']
# ['h08-Fz-33.jpg', 'Health']
# ['h08-Fz-35.jpg', 'Health']
# ['h08-Fz-36.jpg', 'Health']
# ['h08-Fz-37.jpg', 'Health']
# ['h08-Fz-39.jpg', 'Health']
# ['h08-Fz-40.jpg', 'Health']
# ['h08-Fz-38.jpg', 'Health']
# ['h08-Fz-42.jpg', 'Health']
# ['h08-Fz-41.jpg', 'Health']
# ['h08-Fz-43.jpg', 'Health']
# ['h08-Fz-46.jpg', 'Health']
# ['h08-Fz-44.jpg', 'Health']
# ['h08-Fz-45.jpg', 'Health']
# ['h08-Fz-49.jpg', 'Health']
# ['h08-Fz-48.jpg', 'Health']
# ['h08-Fz-47.jpg', 'Health']
# ['h08-Fz-52.jpg', 'Health']
# ['h08-Fz-50.jpg', 'Health']
# ['h08-Fz-51.jpg', 'Health']
# ['h08-Fz-54.jpg', 'Health']
# ['h08-Fz-55.jpg', 'Health']
# ['h08-Fz-53.jpg', 'Health']
# ['h08-Fz-58.jpg', 'Health']
# ['h08-Fz-56.jpg', 'Health']
# ['h08-Fz-57.jpg', 'Health']
# ['h08-Fz-59.jpg', 'Health']
# ['h08-Fz-61.jpg', 'Health']
# ['h08-Fz-60.jpg', 'Health']
# ['h08-Fz-62.jpg', 'Health']
# ['h08-Fz-63.jpg', 'Health']
# ['h08-Fz-64.jpg', 'Health']
# ['h08-Fz-65.jpg', 'Health']
# ['h08-Fz-66.jpg', 'Health']
# ['h08-Fz-67.jpg', 'Health']
# ['h08-Fz-70.jpg', 'Health']
# ['h08-Fz-68.jpg', 'Health']
# ['h08-Fz-69.jpg', 'Health']
# ['h08-Fz-73.jpg', 'Health']
# ['h08-Fz-72.jpg', 'Health']
# ['h08-Fz-71.jpg', 'Health']
# ['h08-Fz-76.jpg', 'Health']
# ['h08-Fz-75.jpg', 'Health']
# ['h08-Fz-74.jpg', 'Health']
# ['h08-Fz-78.jpg', 'Health']
# ['h08-Fz-77.jpg', 'Health']
# ['h08-Fz-79.jpg', 'Health']
# ['h08-Fz-81.jpg', 'Health']
# ['h08-Fz-80.jpg', 'Health']
# ['h08-Fz-84.jpg', 'Health']
# ['h08-Fz-82.jpg', 'Health']
# ['h08-Fz-83.jpg', 'Health']
# ['h08-Fz-87.jpg', 'Health']
# ['h08-Fz-86.jpg', 'Health']
# ['h08-Fz-85.jpg', 'Health']
# ['h08-Fz-89.jpg', 'Health']
# ['h08-Fz-90.jpg', 'Health']
# ['h08-Fz-88.jpg', 'Health']
# ['h08-Fz-91.jpg', 'Health']
# ['h08-Fz-92.jpg', 'Health']
# ['h08-Fz-93.jpg', 'Health']
# ['h08-Fz-95.jpg', 'Health']
# ['h08-Fz-94.jpg', 'Health']
# ['h08-Fz-96.jpg', 'Health']
# ['h08-Fz-97.jpg', 'Health']
# ['h08-Fz-98.jpg', 'Health']
# ['h08-Fz-101.jpg', 'Health']
# ['h08-Fz-100.jpg', 'Health']
# ['h08-Fz-99.jpg', 'Health']
# ['h08-Fz-103.jpg', 'Health']
# ['h08-Fz-102.jpg', 'Health']
# ['h08-Fz-104.jpg', 'Health']
# ['h08-Fz-107.jpg', 'Health']
# ['h08-Fz-105.jpg', 'Health']
# ['h08-Fz-106.jpg', 'Health']
# ['h08-Fz-108.jpg', 'Health']
# ['h08-Fz-109.jpg', 'Health']
# ['h08-Fz-111.jpg', 'Health']
# ['h08-Fz-110.jpg', 'Health']
# ['h08-Fz-112.jpg', 'Health']
# ['h08-Fz-113.jpg', 'Health']
# ['h08-Fz-115.jpg', 'Health']
# ['h08-Fz-114.jpg', 'Health']
# ['h08-Fz-116.jpg', 'Health']
# ['h08-Fz-117.jpg', 'Health']
# ['h08-Fz-120.jpg', 'Health']
# ['h08-Fz-118.jpg', 'Health']
# ['h08-Fz-119.jpg', 'Health']
# ['h08-Fz-123.jpg', 'Health']
# ['h08-Fz-121.jpg', 'Health']
# ['h08-Fz-122.jpg', 'Health']
# ['h08-Fz-126.jpg', 'Health']
# ['h08-Fz-124.jpg', 'Health']
# ['h08-Fz-125.jpg', 'Health']
# ['h08-Fz-129.jpg', 'Health']
# ['h08-Fz-128.jpg', 'Health']
# ['h08-Fz-127.jpg', 'Health']
# ['h08-Fz-131.jpg', 'Health']
# ['h08-Fz-130.jpg', 'Health']
# ['h08-Fz-132.jpg', 'Health']
# ['h08-Fz-133.jpg', 'Health']
# ['h08-Fz-135.jpg', 'Health']
# ['h08-Fz-134.jpg', 'Health']
# ['h08-Fz-136.jpg', 'Health']
# ['h08-Fz-138.jpg', 'Health']
# ['h08-Fz-137.jpg', 'Health']
# ['h08-Fz-141.jpg', 'Health']
# ['h08-Fz-139.jpg', 'Health']
# ['h08-Fz-140.jpg', 'Health']
# ['h08-Fz-144.jpg', 'Health']
# ['h08-Fz-142.jpg', 'Health']
# ['h08-Fz-143.jpg', 'Health']
# ['h08-Fz-145.jpg', 'Health']
# ['h08-Fz-146.jpg', 'Health']
# ['h08-Fz-147.jpg', 'Health']
# ['h08-Fz-148.jpg', 'Health']
# ['h08-Fz-150.jpg', 'Health']
# ['h08-Fz-149.jpg', 'Health']
# ['h08-Fz-152.jpg', 'Health']
# ['h08-Fz-151.jpg', 'Health']
# ['h08-Fz-153.jpg', 'Health']
# ['h08-Fz-156.jpg', 'Health']
# ['h08-Fz-154.jpg', 'Health']
# ['h08-Fz-155.jpg', 'Health']
# ['h08-Fz-158.jpg', 'Health']
# ['h08-Fz-157.jpg', 'Health']
# ['h08-Fz-159.jpg', 'Health']
# ['h08-Fz-162.jpg', 'Health']
# ['h08-Fz-160.jpg', 'Health']
# ['h08-Fz-161.jpg', 'Health']
# ['h08-Fz-165.jpg', 'Health']
# ['h08-Fz-163.jpg', 'Health']
# ['h08-Fz-164.jpg', 'Health']
# ['h08-Fz-167.jpg', 'Health']
# ['h08-Fz-168.jpg', 'Health']
# ['h08-Fz-166.jpg', 'Health']
# ['h08-Fz-169.jpg', 'Health']
# ['h08-Fz-170.jpg', 'Health']
# ['h08-Fz-171.jpg', 'Health']
# ['h08-Fz-173.jpg', 'Health']
# ['h08-Fz-172.jpg', 'Health']
# ['h08-Fz-174.jpg', 'Health']
# ['h08-Fz-175.jpg', 'Health']
# ['h08-Fz-176.jpg', 'Health']
# ['h08-Fz-177.jpg', 'Health']
# ['h08-Fz-179.jpg', 'Health']
# ['h08-Fz-178.jpg', 'Health']
# ['h08-Fz-180.jpg', 'Health']
# ['h08-Fz-181.jpg', 'Health']
# ['h08-Fz-182.jpg', 'Health']
# ['h08-Fz-183.jpg', 'Health']
# ['h08-Fz-184.jpg', 'Health']
# ['h08-Fz-186.jpg', 'Health']
# ['h08-Fz-185.jpg', 'Health']
# ['h08-Fz-187.jpg', 'Health']
# ['h08-Fz-190.jpg', 'Health']
# ['h08-Fz-191.jpg', 'Health']
# ['h08-Fz-188.jpg', 'Health']
# ['h08-Fz-189.jpg', 'Health']
# ['h08-Fz-193.jpg', 'Health']
# ['h08-Fz-192.jpg', 'Health']
# ['h08-Fz-194.jpg', 'Health']
# ['h08-Fz-195.jpg', 'Health']
# ['h08-Fz-196.jpg', 'Health']
# ['h08-Fz-197.jpg', 'Health']
# ['h08-Fz-199.jpg', 'Health']
# ['h08-Fz-198.jpg', 'Health']
# ['h08-Fz-202.jpg', 'Health']
# ['h08-Fz-200.jpg', 'Health']
# ['h08-Fz-201.jpg', 'Health']
# ['h08-Fz-203.jpg', 'Health']
# ['h08-Fz-204.jpg', 'Health']
# ['h08-Fz-205.jpg', 'Health']
# ['h08-Fz-208.jpg', 'Health']
# ['h08-Fz-207.jpg', 'Health']
# ['h08-Fz-206.jpg', 'Health']
# ['h08-Fz-210.jpg', 'Health']
# ['h08-Fz-209.jpg', 'Health']
# ['h08-Cz-0.jpg', 'Health']
# ['h08-Cz-1.jpg', 'Health']
# ['h08-Cz-3.jpg', 'Health']
# ['h08-Cz-2.jpg', 'Health']
# ['h08-Cz-5.jpg', 'Health']
# ['h08-Cz-4.jpg', 'Health']
# ['h08-Cz-6.jpg', 'Health']
# ['h08-Cz-7.jpg', 'Health']
# ['h08-Cz-9.jpg', 'Health']
# ['h08-Cz-8.jpg', 'Health']
# ['h08-Cz-12.jpg', 'Health']
# ['h08-Cz-11.jpg', 'Health']
# ['h08-Cz-10.jpg', 'Health']
# ['h08-Cz-15.jpg', 'Health']
# ['h08-Cz-14.jpg', 'Health']
# ['h08-Cz-13.jpg', 'Health']
# ['h08-Cz-16.jpg', 'Health']
# ['h08-Cz-18.jpg', 'Health']
# ['h08-Cz-17.jpg', 'Health']
# ['h08-Cz-19.jpg', 'Health']
# ['h08-Cz-21.jpg', 'Health']
# ['h08-Cz-20.jpg', 'Health']
# ['h08-Cz-23.jpg', 'Health']
# ['h08-Cz-22.jpg', 'Health']
# ['h08-Cz-24.jpg', 'Health']
# ['h08-Cz-26.jpg', 'Health']
# ['h08-Cz-27.jpg', 'Health']
# ['h08-Cz-25.jpg', 'Health']
# ['h08-Cz-29.jpg', 'Health']
# ['h08-Cz-30.jpg', 'Health']
# ['h08-Cz-28.jpg', 'Health']
# ['h08-Cz-33.jpg', 'Health']
# ['h08-Cz-32.jpg', 'Health']
# ['h08-Cz-31.jpg', 'Health']
# ['h08-Cz-34.jpg', 'Health']
# ['h08-Cz-35.jpg', 'Health']
# ['h08-Cz-36.jpg', 'Health']
# ['h08-Cz-38.jpg', 'Health']
# ['h08-Cz-37.jpg', 'Health']
# ['h08-Cz-41.jpg', 'Health']
# ['h08-Cz-39.jpg', 'Health']
# ['h08-Cz-40.jpg', 'Health']
# ['h08-Cz-44.jpg', 'Health']
# ['h08-Cz-42.jpg', 'Health']
# ['h08-Cz-43.jpg', 'Health']
# ['h08-Cz-45.jpg', 'Health']
# ['h08-Cz-47.jpg', 'Health']
# ['h08-Cz-46.jpg', 'Health']
# ['h08-Cz-48.jpg', 'Health']
# ['h08-Cz-50.jpg', 'Health']
# ['h08-Cz-49.jpg', 'Health']
# ['h08-Cz-54.jpg', 'Health']
# ['h08-Cz-52.jpg', 'Health']
# ['h08-Cz-53.jpg', 'Health']
# ['h08-Cz-51.jpg', 'Health']
# ['h08-Cz-55.jpg', 'Health']
# ['h08-Cz-57.jpg', 'Health']
# ['h08-Cz-56.jpg', 'Health']
# ['h08-Cz-58.jpg', 'Health']
# ['h08-Cz-59.jpg', 'Health']
# ['h08-Cz-60.jpg', 'Health']
# ['h08-Cz-63.jpg', 'Health']
# ['h08-Cz-61.jpg', 'Health']
# ['h08-Cz-62.jpg', 'Health']
# ['h08-Cz-66.jpg', 'Health']
# ['h08-Cz-64.jpg', 'Health']
# ['h08-Cz-67.jpg', 'Health']
# ['h08-Cz-65.jpg', 'Health']
# ['h08-Cz-68.jpg', 'Health']
# ['h08-Cz-69.jpg', 'Health']
# ['h08-Cz-70.jpg', 'Health']
# ['h08-Cz-71.jpg', 'Health']
# ['h08-Cz-72.jpg', 'Health']
# ['h08-Cz-73.jpg', 'Health']
# ['h08-Cz-76.jpg', 'Health']
# ['h08-Cz-74.jpg', 'Health']
# ['h08-Cz-75.jpg', 'Health']
# ['h08-Cz-77.jpg', 'Health']
# ['h08-Cz-79.jpg', 'Health']
# ['h08-Cz-78.jpg', 'Health']
# ['h08-Cz-80.jpg', 'Health']
# ['h08-Cz-81.jpg', 'Health']
# ['h08-Cz-82.jpg', 'Health']
# ['h08-Cz-86.jpg', 'Health']
# ['h08-Cz-84.jpg', 'Health']
# ['h08-Cz-85.jpg', 'Health']
# ['h08-Cz-83.jpg', 'Health']
# ['h08-Cz-89.jpg', 'Health']
# ['h08-Cz-87.jpg', 'Health']
# ['h08-Cz-88.jpg', 'Health']
# ['h08-Cz-90.jpg', 'Health']
# ['h08-Cz-92.jpg', 'Health']
# ['h08-Cz-91.jpg', 'Health']
# ['h08-Cz-93.jpg', 'Health']
# ['h08-Cz-94.jpg', 'Health']
# ['h08-Cz-95.jpg', 'Health']
# ['h08-Cz-97.jpg', 'Health']
# ['h08-Cz-96.jpg', 'Health']
# ['h08-Cz-100.jpg', 'Health']
# ['h08-Cz-98.jpg', 'Health']
# ['h08-Cz-99.jpg', 'Health']
# ['h08-Cz-101.jpg', 'Health']
# ['h08-Cz-102.jpg', 'Health']
# ['h08-Cz-103.jpg', 'Health']
# ['h08-Cz-105.jpg', 'Health']
# ['h08-Cz-106.jpg', 'Health']
# ['h08-Cz-104.jpg', 'Health']
# ['h08-Cz-109.jpg', 'Health']
# ['h08-Cz-108.jpg', 'Health']
# ['h08-Cz-107.jpg', 'Health']
# ['h08-Cz-112.jpg', 'Health']
# ['h08-Cz-110.jpg', 'Health']
# ['h08-Cz-111.jpg', 'Health']
# ['h08-Cz-116.jpg', 'Health']
# ['h08-Cz-115.jpg', 'Health']
# ['h08-Cz-113.jpg', 'Health']
# ['h08-Cz-114.jpg', 'Health']
# ['h08-Cz-117.jpg', 'Health']
# ['h08-Cz-118.jpg', 'Health']
# ['h08-Cz-119.jpg', 'Health']
# ['h08-Cz-120.jpg', 'Health']
# ['h08-Cz-121.jpg', 'Health']
# ['h08-Cz-124.jpg', 'Health']
# ['h08-Cz-122.jpg', 'Health']
# ['h08-Cz-123.jpg', 'Health']
# ['h08-Cz-126.jpg', 'Health']
# ['h08-Cz-127.jpg', 'Health']
# ['h08-Cz-125.jpg', 'Health']
# ['h08-Cz-128.jpg', 'Health']
# ['h08-Cz-130.jpg', 'Health']
# ['h08-Cz-129.jpg', 'Health']
# ['h08-Cz-131.jpg', 'Health']
# ['h08-Cz-133.jpg', 'Health']
# ['h08-Cz-132.jpg', 'Health']
# ['h08-Cz-135.jpg', 'Health']
# ['h08-Cz-134.jpg', 'Health']
# ['h08-Cz-136.jpg', 'Health']
# ['h08-Cz-138.jpg', 'Health']
# ['h08-Cz-139.jpg', 'Health']
# ['h08-Cz-137.jpg', 'Health']
# ['h08-Cz-141.jpg', 'Health']
# ['h08-Cz-140.jpg', 'Health']
# ['h08-Cz-142.jpg', 'Health']
# ['h08-Cz-144.jpg', 'Health']
# ['h08-Cz-145.jpg', 'Health']
# ['h08-Cz-143.jpg', 'Health']
# ['h08-Cz-148.jpg', 'Health']
# ['h08-Cz-146.jpg', 'Health']
# ['h08-Cz-147.jpg', 'Health']
# ['h08-Cz-149.jpg', 'Health']
# ['h08-Cz-150.jpg', 'Health']
# ['h08-Cz-151.jpg', 'Health']
# ['h08-Cz-152.jpg', 'Health']
# ['h08-Cz-153.jpg', 'Health']
# ['h08-Cz-154.jpg', 'Health']
# ['h08-Cz-157.jpg', 'Health']
# ['h08-Cz-155.jpg', 'Health']
# ['h08-Cz-156.jpg', 'Health']
# ['h08-Cz-158.jpg', 'Health']
# ['h08-Cz-160.jpg', 'Health']
# ['h08-Cz-159.jpg', 'Health']
# ['h08-Cz-162.jpg', 'Health']
# ['h08-Cz-161.jpg', 'Health']
# ['h08-Cz-163.jpg', 'Health']
# ['h08-Cz-164.jpg', 'Health']
# ['h08-Cz-165.jpg', 'Health']
# ['h08-Cz-167.jpg', 'Health']
# ['h08-Cz-168.jpg', 'Health']
# ['h08-Cz-166.jpg', 'Health']
# ['h08-Cz-170.jpg', 'Health']
# ['h08-Cz-171.jpg', 'Health']
# ['h08-Cz-169.jpg', 'Health']
# ['h08-Cz-172.jpg', 'Health']
# ['h08-Cz-174.jpg', 'Health']
# ['h08-Cz-173.jpg', 'Health']
# ['h08-Cz-175.jpg', 'Health']
# ['h08-Cz-176.jpg', 'Health']
# ['h08-Cz-180.jpg', 'Health']
# ['h08-Cz-178.jpg', 'Health']
# ['h08-Cz-177.jpg', 'Health']
# ['h08-Cz-179.jpg', 'Health']
# ['h08-Cz-182.jpg', 'Health']
# ['h08-Cz-181.jpg', 'Health']
# ['h08-Cz-185.jpg', 'Health']
# ['h08-Cz-184.jpg', 'Health']
# ['h08-Cz-183.jpg', 'Health']
# ['h08-Cz-186.jpg', 'Health']
# ['h08-Cz-187.jpg', 'Health']
# ['h08-Cz-188.jpg', 'Health']
# ['h08-Cz-189.jpg', 'Health']
# ['h08-Cz-191.jpg', 'Health']
# ['h08-Cz-190.jpg', 'Health']
# ['h08-Cz-192.jpg', 'Health']
# ['h08-Cz-194.jpg', 'Health']
# ['h08-Cz-193.jpg', 'Health']
# ['h08-Cz-197.jpg', 'Health']
# ['h08-Cz-196.jpg', 'Health']
# ['h08-Cz-195.jpg', 'Health']
# ['h08-Cz-198.jpg', 'Health']
# ['h08-Cz-199.jpg', 'Health']
# ['h08-Cz-200.jpg', 'Health']
# ['h08-Cz-202.jpg', 'Health']
# ['h08-Cz-203.jpg', 'Health']
# ['h08-Cz-201.jpg', 'Health']
# ['h08-Cz-206.jpg', 'Health']
# ['h08-Cz-205.jpg', 'Health']
# ['h08-Cz-204.jpg', 'Health']
# ['h08-Cz-207.jpg', 'Health']
# ['h08-Cz-209.jpg', 'Health']
# ['h08-Cz-208.jpg', 'Health']
# ['h08-Pz-0.jpg', 'Health']
# ['h08-Cz-210.jpg', 'Health']
# ['h08-Pz-1.jpg', 'Health']
# ['h08-Pz-3.jpg', 'Health']
# ['h08-Pz-2.jpg', 'Health']
# ['h08-Pz-4.jpg', 'Health']
# ['h08-Pz-5.jpg', 'Health']
# ['h08-Pz-7.jpg', 'Health']
# ['h08-Pz-6.jpg', 'Health']
# ['h08-Pz-10.jpg', 'Health']
# ['h08-Pz-8.jpg', 'Health']
# ['h08-Pz-9.jpg', 'Health']
# ['h08-Pz-11.jpg', 'Health']
# ['h08-Pz-13.jpg', 'Health']
# ['h08-Pz-12.jpg', 'Health']
# ['h08-Pz-15.jpg', 'Health']
# ['h08-Pz-16.jpg', 'Health']
# ['h08-Pz-14.jpg', 'Health']
# ['h08-Pz-17.jpg', 'Health']
# ['h08-Pz-18.jpg', 'Health']
# ['h08-Pz-19.jpg', 'Health']
# ['h08-Pz-22.jpg', 'Health']
# ['h08-Pz-21.jpg', 'Health']
# ['h08-Pz-20.jpg', 'Health']
# ['h08-Pz-24.jpg', 'Health']
# ['h08-Pz-23.jpg', 'Health']
# ['h08-Pz-25.jpg', 'Health']
# ['h08-Pz-26.jpg', 'Health']
# ['h08-Pz-28.jpg', 'Health']
# ['h08-Pz-27.jpg', 'Health']
# ['h08-Pz-30.jpg', 'Health']
# ['h08-Pz-29.jpg', 'Health']
# ['h08-Pz-31.jpg', 'Health']
# ['h08-Pz-34.jpg', 'Health']
# ['h08-Pz-33.jpg', 'Health']
# ['h08-Pz-32.jpg', 'Health']
# ['h08-Pz-36.jpg', 'Health']
# ['h08-Pz-35.jpg', 'Health']
# ['h08-Pz-37.jpg', 'Health']
# ['h08-Pz-38.jpg', 'Health']
# ['h05-Cz-149.jpg', 'Health']
# ['h05-Cz-152.jpg', 'Health']
# ['h05-Cz-150.jpg', 'Health']
# ['h05-Cz-151.jpg', 'Health']
# ['h05-Cz-154.jpg', 'Health']
# ['h05-Cz-155.jpg', 'Health']
# ['h05-Cz-153.jpg', 'Health']
# ['h05-Cz-157.jpg', 'Health']
# ['h05-Cz-158.jpg', 'Health']
# ['h05-Cz-156.jpg', 'Health']
# ['h05-Cz-159.jpg', 'Health']
# ['h05-Cz-160.jpg', 'Health']
# ['h05-Cz-161.jpg', 'Health']
# ['h05-Cz-164.jpg', 'Health']
# ['h05-Cz-163.jpg', 'Health']
# ['h05-Cz-162.jpg', 'Health']
# ['h05-Cz-165.jpg', 'Health']
# ['h05-Cz-167.jpg', 'Health']
# ['h05-Cz-168.jpg', 'Health']
# ['h05-Cz-166.jpg', 'Health']
# ['h05-Cz-169.jpg', 'Health']
# ['h05-Cz-171.jpg', 'Health']
# ['h05-Cz-170.jpg', 'Health']
# ['h05-Cz-172.jpg', 'Health']
# ['h05-Cz-173.jpg', 'Health']
# ['h05-Cz-174.jpg', 'Health']
# ['h05-Cz-177.jpg', 'Health']
# ['h05-Cz-175.jpg', 'Health']
# ['h05-Cz-176.jpg', 'Health']
# ['h05-Cz-178.jpg', 'Health']
# ['h05-Cz-179.jpg', 'Health']
# ['h05-Cz-180.jpg', 'Health']
# ['h05-Cz-181.jpg', 'Health']
# ['h05-Cz-184.jpg', 'Health']
# ['h05-Cz-183.jpg', 'Health']
# ['h05-Cz-182.jpg', 'Health']
# ['h05-Cz-187.jpg', 'Health']
# ['h05-Cz-186.jpg', 'Health']
# ['h05-Cz-185.jpg', 'Health']
# ['h05-Cz-188.jpg', 'Health']
# ['h05-Cz-190.jpg', 'Health']
# ['h05-Cz-189.jpg', 'Health']
# ['h05-Cz-191.jpg', 'Health']
# ['h05-Cz-192.jpg', 'Health']
# ['h05-Cz-193.jpg', 'Health']
# ['h05-Cz-195.jpg', 'Health']
# ['h05-Cz-194.jpg', 'Health']
# ['h05-Cz-196.jpg', 'Health']
# ['h05-Cz-198.jpg', 'Health']
# ['h05-Cz-199.jpg', 'Health']
# ['h05-Cz-197.jpg', 'Health']
# ['h05-Cz-200.jpg', 'Health']
# ['h05-Cz-202.jpg', 'Health']
# ['h05-Cz-201.jpg', 'Health']
# ['h05-Cz-204.jpg', 'Health']
# ['h05-Cz-203.jpg', 'Health']
# ['h05-Cz-205.jpg', 'Health']
# ['h05-Cz-206.jpg', 'Health']
# ['h05-Cz-208.jpg', 'Health']
# ['h05-Cz-207.jpg', 'Health']
# ['h05-Pz-0.jpg', 'Health']
# ['h05-Cz-210.jpg', 'Health']
# ['h05-Cz-209.jpg', 'Health']
# ['h05-Pz-3.jpg', 'Health']
# ['h05-Pz-2.jpg', 'Health']
# ['h05-Pz-1.jpg', 'Health']
# ['h05-Pz-4.jpg', 'Health']
# ['h05-Pz-5.jpg', 'Health']
# ['h05-Pz-9.jpg', 'Health']
# ['h05-Pz-6.jpg', 'Health']
# ['h05-Pz-7.jpg', 'Health']
# ['h05-Pz-8.jpg', 'Health']
# ['h05-Pz-11.jpg', 'Health']
# ['h05-Pz-10.jpg', 'Health']
# ['h05-Pz-14.jpg', 'Health']
# ['h05-Pz-13.jpg', 'Health']
# ['h05-Pz-12.jpg', 'Health']
# ['h05-Pz-17.jpg', 'Health']
# ['h05-Pz-15.jpg', 'Health']
# ['h05-Pz-16.jpg', 'Health']
# ['h05-Pz-19.jpg', 'Health']
# ['h05-Pz-18.jpg', 'Health']
# ['h05-Pz-20.jpg', 'Health']
# ['h05-Pz-22.jpg', 'Health']
# ['h05-Pz-21.jpg', 'Health']
# ['h05-Pz-23.jpg', 'Health']
# ['h05-Pz-24.jpg', 'Health']
# ['h05-Pz-26.jpg', 'Health']
# ['h05-Pz-25.jpg', 'Health']
# ['h05-Pz-27.jpg', 'Health']
# ['h05-Pz-28.jpg', 'Health']
# ['h05-Pz-29.jpg', 'Health']
# ['h05-Pz-32.jpg', 'Health']
# ['h05-Pz-31.jpg', 'Health']
# ['h05-Pz-30.jpg', 'Health']
# ['h05-Pz-34.jpg', 'Health']
# ['h05-Pz-33.jpg', 'Health']
# ['h05-Pz-35.jpg', 'Health']
# ['h05-Pz-38.jpg', 'Health']
# ['h05-Pz-37.jpg', 'Health']
# ['h05-Pz-36.jpg', 'Health']
# ['h05-Pz-39.jpg', 'Health']
# ['h05-Pz-41.jpg', 'Health']
# ['h05-Pz-40.jpg', 'Health']
# ['h05-Pz-42.jpg', 'Health']
# ['h05-Pz-44.jpg', 'Health']
# ['h05-Pz-45.jpg', 'Health']
# ['h05-Pz-43.jpg', 'Health']
# ['h05-Pz-46.jpg', 'Health']
# ['h05-Pz-48.jpg', 'Health']
# ['h05-Pz-47.jpg', 'Health']
# ['h05-Pz-51.jpg', 'Health']
# ['h05-Pz-50.jpg', 'Health']
# ['h05-Pz-49.jpg', 'Health']
# ['h05-Pz-52.jpg', 'Health']
# ['h05-Pz-53.jpg', 'Health']
# ['h05-Pz-54.jpg', 'Health']
# ['h05-Pz-57.jpg', 'Health']
# ['h05-Pz-56.jpg', 'Health']
# ['h05-Pz-55.jpg', 'Health']
# ['h05-Pz-58.jpg', 'Health']
# ['h05-Pz-59.jpg', 'Health']
# ['h05-Pz-60.jpg', 'Health']
# ['h05-Pz-63.jpg', 'Health']
# ['h05-Pz-61.jpg', 'Health']
# ['h05-Pz-62.jpg', 'Health']
# ['h05-Pz-66.jpg', 'Health']
# ['h05-Pz-64.jpg', 'Health']
# ['h05-Pz-65.jpg', 'Health']
# ['h05-Pz-69.jpg', 'Health']
# ['h05-Pz-68.jpg', 'Health']
# ['h05-Pz-67.jpg', 'Health']
# ['h05-Pz-70.jpg', 'Health']
# ['h05-Pz-72.jpg', 'Health']
# ['h05-Pz-71.jpg', 'Health']
# ['h05-Pz-73.jpg', 'Health']
# ['h05-Pz-76.jpg', 'Health']
# ['h05-Pz-74.jpg', 'Health']
# ['h05-Pz-75.jpg', 'Health']
# ['h05-Pz-79.jpg', 'Health']
# ['h05-Pz-78.jpg', 'Health']
# ['h05-Pz-77.jpg', 'Health']
# ['h05-Pz-82.jpg', 'Health']
# ['h05-Pz-81.jpg', 'Health']
# ['h05-Pz-80.jpg', 'Health']
# ['h05-Pz-83.jpg', 'Health']
# ['h05-Pz-84.jpg', 'Health']
# ['h05-Pz-85.jpg', 'Health']
# ['h05-Pz-86.jpg', 'Health']
# ['h05-Pz-87.jpg', 'Health']
# ['h05-Pz-88.jpg', 'Health']
# ['h05-Pz-90.jpg', 'Health']
# ['h05-Pz-91.jpg', 'Health']
# ['h05-Pz-89.jpg', 'Health']
# ['h05-Pz-94.jpg', 'Health']
# ['h05-Pz-93.jpg', 'Health']
# ['h05-Pz-92.jpg', 'Health']
# ['h05-Pz-96.jpg', 'Health']
# ['h05-Pz-95.jpg', 'Health']
# ['h05-Pz-98.jpg', 'Health']
# ['h05-Pz-97.jpg', 'Health']
# ['h05-Pz-99.jpg', 'Health']
# ['h05-Pz-100.jpg', 'Health']
# ['h05-Pz-102.jpg', 'Health']
# ['h05-Pz-101.jpg', 'Health']
# ['h05-Pz-103.jpg', 'Health']
# ['h05-Pz-105.jpg', 'Health']
# ['h05-Pz-104.jpg', 'Health']
# ['h05-Pz-108.jpg', 'Health']
# ['h05-Pz-107.jpg', 'Health']
# ['h05-Pz-106.jpg', 'Health']
# ['h05-Pz-110.jpg', 'Health']
# ['h05-Pz-111.jpg', 'Health']
# ['h05-Pz-109.jpg', 'Health']
# ['h05-Pz-113.jpg', 'Health']
# ['h05-Pz-112.jpg', 'Health']
# ['h05-Pz-114.jpg', 'Health']
# ['h05-Pz-115.jpg', 'Health']
# ['h05-Pz-117.jpg', 'Health']
# ['h05-Pz-116.jpg', 'Health']
# ['h05-Pz-119.jpg', 'Health']
# ['h05-Pz-118.jpg', 'Health']
# ['h05-Pz-120.jpg', 'Health']
# ['h05-Pz-123.jpg', 'Health']
# ['h05-Pz-122.jpg', 'Health']
# ['h05-Pz-121.jpg', 'Health']
# ['h05-Pz-126.jpg', 'Health']
# ['h05-Pz-125.jpg', 'Health']
# ['h05-Pz-124.jpg', 'Health']
# ['h05-Pz-128.jpg', 'Health']
# ['h05-Pz-127.jpg', 'Health']
# ['h05-Pz-129.jpg', 'Health']
# ['h05-Pz-133.jpg', 'Health']
# ['h05-Pz-130.jpg', 'Health']
# ['h05-Pz-131.jpg', 'Health']
# ['h05-Pz-132.jpg', 'Health']
# ['h05-Pz-134.jpg', 'Health']
# ['h05-Pz-135.jpg', 'Health']
# ['h05-Pz-136.jpg', 'Health']
# ['h05-Pz-138.jpg', 'Health']
# ['h05-Pz-137.jpg', 'Health']
# ['h05-Pz-139.jpg', 'Health']
# ['h05-Pz-140.jpg', 'Health']
# ['h05-Pz-141.jpg', 'Health']
# ['h05-Pz-145.jpg', 'Health']
# ['h05-Pz-143.jpg', 'Health']
# ['h05-Pz-144.jpg', 'Health']
# ['h05-Pz-142.jpg', 'Health']
# ['h05-Pz-147.jpg', 'Health']
# ['h05-Pz-148.jpg', 'Health']
# ['h05-Pz-146.jpg', 'Health']
# ['h05-Pz-149.jpg', 'Health']
# ['h05-Pz-151.jpg', 'Health']
# ['h05-Pz-150.jpg', 'Health']
# ['h05-Pz-152.jpg', 'Health']
# ['h05-Pz-153.jpg', 'Health']
# ['h05-Pz-154.jpg', 'Health']
# ['h05-Pz-157.jpg', 'Health']
# ['h05-Pz-155.jpg', 'Health']
# ['h05-Pz-156.jpg', 'Health']
# ['h05-Pz-160.jpg', 'Health']
# ['h05-Pz-158.jpg', 'Health']
# ['h05-Pz-159.jpg', 'Health']
# ['h05-Pz-162.jpg', 'Health']
# ['h05-Pz-161.jpg', 'Health']
# ['h05-Pz-164.jpg', 'Health']
# ['h05-Pz-163.jpg', 'Health']
# ['h05-Pz-166.jpg', 'Health']
# ['h05-Pz-165.jpg', 'Health']
# ['h05-Pz-167.jpg', 'Health']
# ['h05-Pz-169.jpg', 'Health']
# ['h05-Pz-168.jpg', 'Health']
# ['h05-Pz-171.jpg', 'Health']
# ['h05-Pz-172.jpg', 'Health']
# ['h05-Pz-170.jpg', 'Health']
# ['h05-Pz-173.jpg', 'Health']
# ['h05-Pz-175.jpg', 'Health']
# ['h05-Pz-174.jpg', 'Health']
# ['h05-Pz-178.jpg', 'Health']
# ['h05-Pz-176.jpg', 'Health']
# ['h05-Pz-177.jpg', 'Health']
# ['h05-Pz-180.jpg', 'Health']
# ['h05-Pz-181.jpg', 'Health']
# ['h05-Pz-179.jpg', 'Health']
# ['h05-Pz-183.jpg', 'Health']
# ['h05-Pz-184.jpg', 'Health']
# ['h05-Pz-182.jpg', 'Health']
# ['h05-Pz-187.jpg', 'Health']
# ['h05-Pz-186.jpg', 'Health']
# ['h05-Pz-185.jpg', 'Health']
# ['h05-Pz-189.jpg', 'Health']
# ['h05-Pz-188.jpg', 'Health']
# ['h05-Pz-190.jpg', 'Health']
# ['h05-Pz-193.jpg', 'Health']
# ['h05-Pz-191.jpg', 'Health']
# ['h05-Pz-192.jpg', 'Health']
# ['h05-Pz-195.jpg', 'Health']
# ['h05-Pz-196.jpg', 'Health']
# ['h05-Pz-194.jpg', 'Health']
# ['h05-Pz-197.jpg', 'Health']
# ['h05-Pz-199.jpg', 'Health']
# ['h05-Pz-198.jpg', 'Health']
# ['h05-Pz-200.jpg', 'Health']
# ['h05-Pz-203.jpg', 'Health']
# ['h05-Pz-201.jpg', 'Health']
# ['h05-Pz-202.jpg', 'Health']
# ['h05-Pz-204.jpg', 'Health']
# ['h05-Pz-205.jpg', 'Health']
# ['h05-Pz-206.jpg', 'Health']
# ['h05-Pz-207.jpg', 'Health']
# ['h05-Pz-208.jpg', 'Health']
# ['h05-Pz-209.jpg', 'Health']
# ['h06-Fz-0.jpg', 'Health']
# ['h05-Pz-210.jpg', 'Health']
# ['h06-Fz-1.jpg', 'Health']
# ['h06-Fz-4.jpg', 'Health']
# ['h06-Fz-2.jpg', 'Health']
# ['h06-Fz-3.jpg', 'Health']
# ['h06-Fz-5.jpg', 'Health']
# ['h06-Fz-6.jpg', 'Health']
# ['h06-Fz-7.jpg', 'Health']
# ['h06-Fz-10.jpg', 'Health']
# ['h06-Fz-9.jpg', 'Health']
# ['h06-Fz-8.jpg', 'Health']
# ['h06-Fz-13.jpg', 'Health']
# ['h06-Fz-12.jpg', 'Health']
# ['h06-Fz-11.jpg', 'Health']
# ['h06-Fz-16.jpg', 'Health']
# ['h06-Fz-15.jpg', 'Health']
# ['h06-Fz-14.jpg', 'Health']
# ['h06-Fz-19.jpg', 'Health']
# ['h06-Fz-17.jpg', 'Health']
# ['h06-Fz-18.jpg', 'Health']
# ['h06-Fz-21.jpg', 'Health']
# ['h06-Fz-20.jpg', 'Health']
# ['h06-Fz-22.jpg', 'Health']
# ['h06-Fz-25.jpg', 'Health']
# ['h06-Fz-23.jpg', 'Health']
# ['h06-Fz-24.jpg', 'Health']
# ['h06-Fz-26.jpg', 'Health']
# ['h06-Fz-28.jpg', 'Health']
# ['h06-Fz-27.jpg', 'Health']
# ['h06-Fz-30.jpg', 'Health']
# ['h06-Fz-31.jpg', 'Health']
# ['h06-Fz-29.jpg', 'Health']
# ['h06-Fz-34.jpg', 'Health']
# ['h06-Fz-33.jpg', 'Health']
# ['h06-Fz-32.jpg', 'Health']
# ['h06-Fz-37.jpg', 'Health']
# ['h06-Fz-35.jpg', 'Health']
# ['h06-Fz-36.jpg', 'Health']
# ['h06-Fz-40.jpg', 'Health']
# ['h06-Fz-38.jpg', 'Health']
# ['h06-Fz-39.jpg', 'Health']
# ['h06-Fz-42.jpg', 'Health']
# ['h06-Fz-43.jpg', 'Health']
# ['h06-Fz-41.jpg', 'Health']
# ['h06-Fz-45.jpg', 'Health']
# ['h06-Fz-46.jpg', 'Health']
# ['h06-Fz-44.jpg', 'Health']
# ['h06-Fz-47.jpg', 'Health']
# ['h06-Fz-49.jpg', 'Health']
# ['h06-Fz-48.jpg', 'Health']
# ['h06-Fz-52.jpg', 'Health']
# ['h06-Fz-53.jpg', 'Health']
# ['h06-Fz-50.jpg', 'Health']
# ['h06-Fz-51.jpg', 'Health']
# ['h06-Fz-54.jpg', 'Health']
# ['h06-Fz-55.jpg', 'Health']
# ['h06-Fz-56.jpg', 'Health']
# ['h06-Fz-59.jpg', 'Health']
# ['h06-Fz-57.jpg', 'Health']
# ['h06-Fz-58.jpg', 'Health']
# ['h06-Fz-62.jpg', 'Health']
# ['h06-Fz-60.jpg', 'Health']
# ['h06-Fz-61.jpg', 'Health']
# ['h06-Fz-65.jpg', 'Health']
# ['h06-Fz-64.jpg', 'Health']
# ['h06-Fz-63.jpg', 'Health']
# ['h06-Fz-68.jpg', 'Health']
# ['h06-Fz-67.jpg', 'Health']
# ['h06-Fz-66.jpg', 'Health']
# ['h06-Fz-71.jpg', 'Health']
# ['h06-Fz-69.jpg', 'Health']
# ['h06-Fz-70.jpg', 'Health']
# ['h06-Fz-74.jpg', 'Health']
# ['h06-Fz-73.jpg', 'Health']
# ['h06-Fz-72.jpg', 'Health']
# ['h06-Fz-77.jpg', 'Health']
# ['h06-Fz-75.jpg', 'Health']
# ['h06-Fz-76.jpg', 'Health']
# ['h06-Fz-79.jpg', 'Health']
# ['h06-Fz-78.jpg', 'Health']
# ['h06-Fz-80.jpg', 'Health']
# ['h06-Fz-82.jpg', 'Health']
# ['h06-Fz-81.jpg', 'Health']
# ['h06-Fz-83.jpg', 'Health']
# ['h06-Fz-85.jpg', 'Health']
# ['h06-Fz-84.jpg', 'Health']
# ['h06-Fz-87.jpg', 'Health']
# ['h06-Fz-86.jpg', 'Health']
# ['h06-Fz-88.jpg', 'Health']
# ['h06-Fz-90.jpg', 'Health']
# ['h06-Fz-89.jpg', 'Health']
# ['h06-Fz-91.jpg', 'Health']
# ['h06-Fz-94.jpg', 'Health']
# ['h06-Fz-92.jpg', 'Health']
# ['h06-Fz-93.jpg', 'Health']
# ['h06-Fz-95.jpg', 'Health']
# ['h06-Fz-97.jpg', 'Health']
# ['h06-Fz-96.jpg', 'Health']
# ['h06-Fz-98.jpg', 'Health']
# ['h06-Fz-100.jpg', 'Health']
# ['h06-Fz-99.jpg', 'Health']
# ['h06-Fz-103.jpg', 'Health']
# ['h06-Fz-102.jpg', 'Health']
# ['h06-Fz-101.jpg', 'Health']
# ['h06-Fz-106.jpg', 'Health']
# ['h06-Fz-104.jpg', 'Health']
# ['h06-Fz-105.jpg', 'Health']
# ['h06-Fz-109.jpg', 'Health']
# ['h06-Fz-108.jpg', 'Health']
# ['h06-Fz-107.jpg', 'Health']
# ['h06-Fz-110.jpg', 'Health']
# ['h06-Fz-112.jpg', 'Health']
# ['h06-Fz-111.jpg', 'Health']
# ['h06-Fz-114.jpg', 'Health']
# ['h06-Fz-113.jpg', 'Health']
# ['h06-Fz-115.jpg', 'Health']
# ['h06-Fz-117.jpg', 'Health']
# ['h06-Fz-118.jpg', 'Health']
# ['h06-Fz-116.jpg', 'Health']
# ['h06-Fz-120.jpg', 'Health']
# ['h06-Fz-122.jpg', 'Health']
# ['h06-Fz-121.jpg', 'Health']
# ['h06-Fz-119.jpg', 'Health']
# ['h06-Fz-123.jpg', 'Health']
# ['h06-Fz-125.jpg', 'Health']
# ['h06-Fz-124.jpg', 'Health']
# ['h06-Fz-127.jpg', 'Health']
# ['h06-Fz-128.jpg', 'Health']
# ['h06-Fz-126.jpg', 'Health']
# ['h06-Fz-129.jpg', 'Health']
# ['h06-Fz-130.jpg', 'Health']
# ['h06-Fz-131.jpg', 'Health']
# ['h06-Fz-132.jpg', 'Health']
# ['h06-Fz-134.jpg', 'Health']
# ['h06-Fz-133.jpg', 'Health']
# ['h06-Fz-136.jpg', 'Health']
# ['h06-Fz-135.jpg', 'Health']
# ['h06-Fz-137.jpg', 'Health']
# ['h06-Fz-138.jpg', 'Health']
# ['h06-Fz-140.jpg', 'Health']
# ['h06-Fz-141.jpg', 'Health']
# ['h06-Fz-139.jpg', 'Health']
# ['h06-Fz-142.jpg', 'Health']
# ['h06-Fz-143.jpg', 'Health']
# ['h06-Fz-144.jpg', 'Health']
# ['h06-Fz-147.jpg', 'Health']
# ['h06-Fz-146.jpg', 'Health']
# ['h06-Fz-145.jpg', 'Health']
# ['h06-Fz-150.jpg', 'Health']
# ['h06-Fz-149.jpg', 'Health']
# ['h06-Fz-148.jpg', 'Health']
# ['h06-Fz-153.jpg', 'Health']
# ['h06-Fz-151.jpg', 'Health']
# ['h06-Fz-152.jpg', 'Health']
# ['h06-Fz-157.jpg', 'Health']
# ['h06-Fz-156.jpg', 'Health']
# ['h06-Fz-154.jpg', 'Health']
# ['h06-Fz-155.jpg', 'Health']
# ['h06-Fz-158.jpg', 'Health']
# ['h06-Fz-159.jpg', 'Health']
# ['h06-Fz-160.jpg', 'Health']
# ['h06-Fz-162.jpg', 'Health']
# ['h06-Fz-163.jpg', 'Health']
# ['h06-Fz-161.jpg', 'Health']
# ['h06-Fz-166.jpg', 'Health']
# ['h06-Fz-164.jpg', 'Health']
# ['h06-Fz-165.jpg', 'Health']
# ['h06-Fz-169.jpg', 'Health']
# ['h06-Fz-168.jpg', 'Health']
# ['h06-Fz-167.jpg', 'Health']
# ['h06-Fz-171.jpg', 'Health']
# ['h06-Fz-172.jpg', 'Health']
# ['h06-Fz-170.jpg', 'Health']
# ['h06-Fz-174.jpg', 'Health']
# ['h06-Fz-176.jpg', 'Health']
# ['h06-Fz-175.jpg', 'Health']
# ['h06-Fz-173.jpg', 'Health']
# ['h06-Fz-179.jpg', 'Health']
# ['h06-Fz-178.jpg', 'Health']
# ['h06-Fz-177.jpg', 'Health']
# ['h06-Fz-181.jpg', 'Health']
# ['h06-Fz-182.jpg', 'Health']
# ['h06-Fz-180.jpg', 'Health']
# ['h06-Fz-183.jpg', 'Health']
# ['h06-Fz-184.jpg', 'Health']
# ['h06-Fz-185.jpg', 'Health']
# ['h06-Fz-187.jpg', 'Health']
# ['h06-Fz-188.jpg', 'Health']
# ['h06-Fz-186.jpg', 'Health']
# ['h06-Fz-189.jpg', 'Health']
# ['h06-Fz-190.jpg', 'Health']
# ['h06-Fz-191.jpg', 'Health']
# ['h06-Fz-192.jpg', 'Health']
# ['h06-Fz-193.jpg', 'Health']
# ['h06-Fz-194.jpg', 'Health']
# ['h06-Fz-197.jpg', 'Health']
# ['h06-Fz-196.jpg', 'Health']
# ['h06-Fz-195.jpg', 'Health']
# ['h06-Fz-198.jpg', 'Health']
# ['h06-Fz-199.jpg', 'Health']
# ['h06-Fz-200.jpg', 'Health']
# ['h06-Fz-201.jpg', 'Health']
# ['h06-Fz-202.jpg', 'Health']
# ['h06-Fz-203.jpg', 'Health']
# ['h06-Fz-204.jpg', 'Health']
# ['h06-Fz-205.jpg', 'Health']
# ['h06-Fz-206.jpg', 'Health']
# ['h06-Fz-209.jpg', 'Health']
# ['h06-Fz-207.jpg', 'Health']
# ['h06-Fz-208.jpg', 'Health']
# ['h06-Fz-210.jpg', 'Health']
# ['h06-Cz-0.jpg', 'Health']
# ['h06-Cz-1.jpg', 'Health']
# ['h06-Cz-2.jpg', 'Health']
# ['h06-Cz-3.jpg', 'Health']
# ['h06-Cz-4.jpg', 'Health']
# ['h06-Cz-5.jpg', 'Health']
# ['h06-Cz-6.jpg', 'Health']
# ['h06-Cz-8.jpg', 'Health']
# ['h06-Cz-9.jpg', 'Health']
# ['h06-Cz-7.jpg', 'Health']
# ['h06-Cz-12.jpg', 'Health']
# ['h06-Cz-10.jpg', 'Health']
# ['h06-Cz-11.jpg', 'Health']
# ['h06-Cz-13.jpg', 'Health']
# ['h06-Cz-15.jpg', 'Health']
# ['h06-Cz-14.jpg', 'Health']
# ['h06-Cz-17.jpg', 'Health']
# ['h06-Cz-16.jpg', 'Health']
# ['h06-Cz-18.jpg', 'Health']
# ['h06-Cz-21.jpg', 'Health']
# ['h06-Cz-19.jpg', 'Health']
# ['h06-Cz-20.jpg', 'Health']
# ['h06-Cz-24.jpg', 'Health']
# ['h06-Cz-22.jpg', 'Health']
# ['h06-Cz-23.jpg', 'Health']
# ['h06-Cz-25.jpg', 'Health']
# ['h06-Cz-27.jpg', 'Health']
# ['h06-Cz-26.jpg', 'Health']
# ['h06-Cz-29.jpg', 'Health']
# ['h06-Cz-30.jpg', 'Health']
# ['h06-Cz-28.jpg', 'Health']
# ['h06-Cz-33.jpg', 'Health']
# ['h06-Cz-31.jpg', 'Health']
# ['h06-Cz-32.jpg', 'Health']
# ['h06-Cz-36.jpg', 'Health']
# ['h06-Cz-37.jpg', 'Health']
# ['h06-Cz-34.jpg', 'Health']
# ['h06-Cz-35.jpg', 'Health']
# ['h06-Cz-39.jpg', 'Health']
# ['h06-Cz-38.jpg', 'Health']
# ['h06-Cz-40.jpg', 'Health']
# ['h06-Cz-41.jpg', 'Health']
# ['h06-Cz-42.jpg', 'Health']
# ['h06-Cz-43.jpg', 'Health']
# ['h06-Cz-45.jpg', 'Health']
# ['h06-Cz-46.jpg', 'Health']
# ['h06-Cz-44.jpg', 'Health']
# ['h06-Cz-49.jpg', 'Health']
# ['h06-Cz-47.jpg', 'Health']
# ['h06-Cz-48.jpg', 'Health']
# ['h06-Cz-52.jpg', 'Health']
# ['h06-Cz-51.jpg', 'Health']
# ['h06-Cz-50.jpg', 'Health']
# ['h06-Cz-55.jpg', 'Health']
# ['h06-Cz-53.jpg', 'Health']
# ['h06-Cz-54.jpg', 'Health']
# ['h06-Cz-58.jpg', 'Health']
# ['h06-Cz-56.jpg', 'Health']
# ['h06-Cz-57.jpg', 'Health']
# ['h06-Cz-59.jpg', 'Health']
# ['h06-Cz-61.jpg', 'Health']
# ['h06-Cz-60.jpg', 'Health']
# ['h06-Cz-64.jpg', 'Health']
# ['h06-Cz-62.jpg', 'Health']
# ['h06-Cz-63.jpg', 'Health']
# ['h06-Cz-65.jpg', 'Health']
# ['h06-Cz-67.jpg', 'Health']
# ['h06-Cz-66.jpg', 'Health']
# ['h06-Cz-69.jpg', 'Health']
# ['h06-Cz-68.jpg', 'Health']
# ['h06-Cz-70.jpg', 'Health']
# ['h06-Cz-73.jpg', 'Health']
# ['h06-Cz-72.jpg', 'Health']
# ['h06-Cz-71.jpg', 'Health']
# ['h06-Cz-74.jpg', 'Health']
# ['h06-Cz-76.jpg', 'Health']
# ['h06-Cz-75.jpg', 'Health']
# ['h06-Cz-77.jpg', 'Health']
# ['h06-Cz-78.jpg', 'Health']
# ['h06-Cz-79.jpg', 'Health']
# ['h06-Cz-82.jpg', 'Health']
# ['h06-Cz-81.jpg', 'Health']
# ['h06-Cz-80.jpg', 'Health']
# ['h06-Cz-84.jpg', 'Health']
# ['h06-Cz-85.jpg', 'Health']
# ['h06-Cz-83.jpg', 'Health']
# ['h06-Cz-88.jpg', 'Health']
# ['h06-Cz-86.jpg', 'Health']
# ['h06-Cz-87.jpg', 'Health']
# ...
# ['h01-Cz-120.jpg', 'Health']
# ['h01-Cz-122.jpg', 'Health']
# ['h01-Cz-121.jpg', 'Health']
# ['h01-Cz-125.jpg', 'Health']
# ['h01-Cz-123.jpg', 'Health']
# ['h01-Cz-124.jpg', 'Health']
# ['h01-Cz-126.jpg', 'Health']
# ['h01-Cz-127.jpg', 'Health']
# ['h01-Cz-129.jpg', 'Health']
# ['h01-Cz-128.jpg', 'Health']
# ['h01-Cz-130.jpg', 'Health']
# ['h01-Cz-131.jpg', 'Health']
# ['h01-Cz-133.jpg', 'Health']
# ['h01-Cz-132.jpg', 'Health']
# ['h01-Cz-134.jpg', 'Health']
# ['h01-Cz-135.jpg', 'Health']
# ['h01-Cz-136.jpg', 'Health']
# ['h01-Cz-137.jpg', 'Health']
# ['h01-Cz-139.jpg', 'Health']
# ['h01-Cz-138.jpg', 'Health']
# ['h01-Cz-140.jpg', 'Health']
# ['h01-Cz-142.jpg', 'Health']
# ['h01-Cz-141.jpg', 'Health']
# ['h01-Cz-144.jpg', 'Health']
# ['h01-Cz-143.jpg', 'Health']
# ['h01-Cz-146.jpg', 'Health']
# ['h01-Cz-145.jpg', 'Health']
# ['h01-Cz-149.jpg', 'Health']
# ['h01-Cz-147.jpg', 'Health']
# ['h01-Cz-148.jpg', 'Health']
# ['h01-Cz-150.jpg', 'Health']
# ['h01-Cz-152.jpg', 'Health']
# ['h01-Cz-151.jpg', 'Health']
# ['h01-Cz-155.jpg', 'Health']
# ['h01-Cz-153.jpg', 'Health']
# ['h01-Cz-154.jpg', 'Health']
# ['h01-Cz-157.jpg', 'Health']
# ['h01-Cz-156.jpg', 'Health']
# ['h01-Cz-158.jpg', 'Health']
# ['h01-Cz-159.jpg', 'Health']
# ['h01-Cz-161.jpg', 'Health']
# ['h01-Cz-160.jpg', 'Health']
# ['h01-Cz-162.jpg', 'Health']
# ['h01-Cz-163.jpg', 'Health']
# ['h01-Cz-165.jpg', 'Health']
# ['h01-Cz-164.jpg', 'Health']
# ['h01-Cz-166.jpg', 'Health']
# ['h01-Cz-167.jpg', 'Health']
# ['h01-Cz-169.jpg', 'Health']
# ['h01-Cz-168.jpg', 'Health']
# ['h01-Cz-171.jpg', 'Health']
# ['h01-Cz-170.jpg', 'Health']
# ['h01-Cz-172.jpg', 'Health']
# ['h01-Cz-173.jpg', 'Health']
# ['h01-Cz-174.jpg', 'Health']
# ['h01-Cz-176.jpg', 'Health']
# ['h01-Cz-175.jpg', 'Health']
# ['h01-Cz-178.jpg', 'Health']
# ['h01-Cz-177.jpg', 'Health']
# ['h01-Cz-179.jpg', 'Health']
# ['h01-Cz-180.jpg', 'Health']
# ['h01-Cz-181.jpg', 'Health']
# ['h01-Cz-182.jpg', 'Health']
# ['h01-Cz-184.jpg', 'Health']
# ['h01-Cz-183.jpg', 'Health']
# ['h01-Cz-186.jpg', 'Health']
# ['h01-Cz-185.jpg', 'Health']
# ['h01-Cz-188.jpg', 'Health']
# ['h01-Cz-189.jpg', 'Health']
# ['h01-Cz-187.jpg', 'Health']
# ['h01-Cz-190.jpg', 'Health']
# ['h01-Cz-191.jpg', 'Health']
# ['h01-Cz-192.jpg', 'Health']
# ['h01-Cz-196.jpg', 'Health']
# ['h01-Cz-194.jpg', 'Health']
# ['h01-Cz-193.jpg', 'Health']
# ['h01-Cz-195.jpg', 'Health']
# ['h01-Cz-199.jpg', 'Health']
# ['h01-Cz-197.jpg', 'Health']
# ['h01-Cz-198.jpg', 'Health']
# ['h01-Cz-202.jpg', 'Health']
# ['h01-Cz-201.jpg', 'Health']
# ['h01-Cz-200.jpg', 'Health']
# ['h01-Cz-203.jpg', 'Health']
# ['h01-Cz-206.jpg', 'Health']
# ['h01-Cz-205.jpg', 'Health']
# ['h01-Cz-204.jpg', 'Health']
# ['h01-Cz-208.jpg', 'Health']
# ['h01-Cz-207.jpg', 'Health']
# ['h01-Pz-0.jpg', 'Health']
# ['h01-Cz-210.jpg', 'Health']
# ['h01-Pz-1.jpg', 'Health']
# ['h01-Cz-209.jpg', 'Health']
# ['h01-Pz-4.jpg', 'Health']
# ['h01-Pz-3.jpg', 'Health']
# ['h01-Pz-2.jpg', 'Health']
# ['h01-Pz-6.jpg', 'Health']
# ['h01-Pz-7.jpg', 'Health']
# ['h01-Pz-5.jpg', 'Health']
# ['h01-Pz-8.jpg', 'Health']
# ['h01-Pz-9.jpg', 'Health']
# ['h01-Pz-10.jpg', 'Health']
# ['h01-Pz-12.jpg', 'Health']
# ['h01-Pz-11.jpg', 'Health']
# ['h01-Pz-13.jpg', 'Health']
# ['h01-Pz-14.jpg', 'Health']
# ['h01-Pz-16.jpg', 'Health']
# ['h01-Pz-15.jpg', 'Health']
# ['h01-Pz-19.jpg', 'Health']
# ['h01-Pz-20.jpg', 'Health']
# ['h01-Pz-17.jpg', 'Health']
# ['h01-Pz-18.jpg', 'Health']
# ['h01-Pz-23.jpg', 'Health']
# ['h01-Pz-21.jpg', 'Health']
# ['h01-Pz-22.jpg', 'Health']
# ['h01-Pz-27.jpg', 'Health']
# ['h01-Pz-25.jpg', 'Health']
# ['h01-Pz-26.jpg', 'Health']
# ['h01-Pz-24.jpg', 'Health']
# ['h01-Pz-29.jpg', 'Health']
# ['h01-Pz-28.jpg', 'Health']
# ['h01-Pz-30.jpg', 'Health']
# ['h01-Pz-31.jpg', 'Health']
# ['h01-Pz-33.jpg', 'Health']
# ['h01-Pz-34.jpg', 'Health']
# ['h01-Pz-32.jpg', 'Health']
# ['h01-Pz-37.jpg', 'Health']
# ['h01-Pz-35.jpg', 'Health']
# ['h01-Pz-36.jpg', 'Health']
# ['h01-Pz-38.jpg', 'Health']
# ['h01-Pz-40.jpg', 'Health']
# ['h01-Pz-39.jpg', 'Health']
# ['h01-Pz-42.jpg', 'Health']
# ['h01-Pz-41.jpg', 'Health']
# ['h01-Pz-43.jpg', 'Health']
# ['h01-Pz-44.jpg', 'Health']
# ['h01-Pz-47.jpg', 'Health']
# ['h01-Pz-46.jpg', 'Health']
# ['h01-Pz-45.jpg', 'Health']
# ['h01-Pz-49.jpg', 'Health']
# ['h01-Pz-50.jpg', 'Health']
# ['h01-Pz-48.jpg', 'Health']
# ['h01-Pz-52.jpg', 'Health']
# ['h01-Pz-53.jpg', 'Health']
# ['h01-Pz-51.jpg', 'Health']
# ['h01-Pz-54.jpg', 'Health']
# ['h01-Pz-56.jpg', 'Health']
# ['h01-Pz-55.jpg', 'Health']
# ['h01-Pz-57.jpg', 'Health']
# ['h01-Pz-59.jpg', 'Health']
# ['h01-Pz-58.jpg', 'Health']
# ['h01-Pz-60.jpg', 'Health']
# ['h01-Pz-61.jpg', 'Health']
# ['h01-Pz-62.jpg', 'Health']
# ['h01-Pz-63.jpg', 'Health']
# ['h01-Pz-64.jpg', 'Health']
# ['h01-Pz-66.jpg', 'Health']
# ['h01-Pz-65.jpg', 'Health']
# ['h01-Pz-67.jpg', 'Health']
# ['h01-Pz-68.jpg', 'Health']
# ['h01-Pz-69.jpg', 'Health']
# ['h01-Pz-70.jpg', 'Health']
# ['h01-Pz-71.jpg', 'Health']
# ['h01-Pz-72.jpg', 'Health']
# ['h01-Pz-74.jpg', 'Health']
# ['h01-Pz-75.jpg', 'Health']
# ['h01-Pz-73.jpg', 'Health']
# ['h01-Pz-76.jpg', 'Health']
# ['h01-Pz-77.jpg', 'Health']
# ['h01-Pz-78.jpg', 'Health']
# ['h01-Pz-79.jpg', 'Health']
# ['h01-Pz-80.jpg', 'Health']
# ['h01-Pz-81.jpg', 'Health']
# ['h01-Pz-82.jpg', 'Health']
# ['h01-Pz-83.jpg', 'Health']
# ['h01-Pz-85.jpg', 'Health']
# ['h01-Pz-84.jpg', 'Health']
# ['h01-Pz-88.jpg', 'Health']
# ['h01-Pz-86.jpg', 'Health']
# ['h01-Pz-87.jpg', 'Health']
# ['h01-Pz-89.jpg', 'Health']
# ['h01-Pz-91.jpg', 'Health']
# ['h01-Pz-90.jpg', 'Health']
# ['h01-Pz-94.jpg', 'Health']
# ['h01-Pz-92.jpg', 'Health']
# ['h01-Pz-93.jpg', 'Health']
# ['h01-Pz-95.jpg', 'Health']
# ['h01-Pz-98.jpg', 'Health']
# ['h01-Pz-96.jpg', 'Health']
# ['h01-Pz-97.jpg', 'Health']
# ['h01-Pz-99.jpg', 'Health']
# ['h01-Pz-100.jpg', 'Health']
# ['h01-Pz-102.jpg', 'Health']
# ['h01-Pz-104.jpg', 'Health']
# ['h01-Pz-101.jpg', 'Health']
# ['h01-Pz-103.jpg', 'Health']
# ['h01-Pz-107.jpg', 'Health']
# ['h01-Pz-105.jpg', 'Health']
# ['h01-Pz-106.jpg', 'Health']
# ['h01-Pz-109.jpg', 'Health']
# ['h01-Pz-108.jpg', 'Health']
# ['h01-Pz-110.jpg', 'Health']
# ['h01-Pz-113.jpg', 'Health']
# ['h01-Pz-112.jpg', 'Health']
# ['h01-Pz-111.jpg', 'Health']
# ['h01-Pz-114.jpg', 'Health']
# ['h01-Pz-115.jpg', 'Health']
# ['h01-Pz-116.jpg', 'Health']
# ['h01-Pz-117.jpg', 'Health']
# ['h01-Pz-118.jpg', 'Health']
# ['h01-Pz-119.jpg', 'Health']
# ['h01-Pz-120.jpg', 'Health']
# ['h01-Pz-122.jpg', 'Health']
# ['h01-Pz-121.jpg', 'Health']
# ['h01-Pz-123.jpg', 'Health']
# ['h01-Pz-125.jpg', 'Health']
# ['h01-Pz-124.jpg', 'Health']
# ['h01-Pz-127.jpg', 'Health']
# ['h01-Pz-128.jpg', 'Health']
# ['h01-Pz-126.jpg', 'Health']
# ['h01-Pz-131.jpg', 'Health']
# ['h01-Pz-132.jpg', 'Health']
# ['h01-Pz-129.jpg', 'Health']
# ['h01-Pz-130.jpg', 'Health']
# ['h01-Pz-134.jpg', 'Health']
# ['h01-Pz-135.jpg', 'Health']
# ['h01-Pz-133.jpg', 'Health']
# ['h01-Pz-138.jpg', 'Health']
# ['h01-Pz-136.jpg', 'Health']
# ['h01-Pz-137.jpg', 'Health']
# ['h01-Pz-139.jpg', 'Health']
# ['h01-Pz-141.jpg', 'Health']
# ['h01-Pz-140.jpg', 'Health']
# ['h01-Pz-142.jpg', 'Health']
# ['h01-Pz-143.jpg', 'Health']
# ['h01-Pz-144.jpg', 'Health']
# ['h01-Pz-147.jpg', 'Health']
# ['h01-Pz-145.jpg', 'Health']
# ['h01-Pz-146.jpg', 'Health']
# ['h01-Pz-151.jpg', 'Health']
# ['h01-Pz-148.jpg', 'Health']
# ['h01-Pz-150.jpg', 'Health']
# ['h01-Pz-149.jpg', 'Health']
# ['h01-Pz-152.jpg', 'Health']
# ['h01-Pz-154.jpg', 'Health']
# ['h01-Pz-153.jpg', 'Health']
# ['h01-Pz-155.jpg', 'Health']
# ['h01-Pz-156.jpg', 'Health']
# ['h01-Pz-157.jpg', 'Health']
# ['h01-Pz-158.jpg', 'Health']
# ['h01-Pz-159.jpg', 'Health']
# ['h01-Pz-160.jpg', 'Health']
# ['h01-Pz-161.jpg', 'Health']
# ['h01-Pz-164.jpg', 'Health']
# ['h01-Pz-162.jpg', 'Health']
# ['h01-Pz-163.jpg', 'Health']
# ['h01-Pz-167.jpg', 'Health']
# ['h01-Pz-165.jpg', 'Health']
# ['h01-Pz-166.jpg', 'Health']
# ['h01-Pz-170.jpg', 'Health']
# ['h01-Pz-169.jpg', 'Health']
# ['h01-Pz-168.jpg', 'Health']
# ['h01-Pz-173.jpg', 'Health']
# ['h01-Pz-172.jpg', 'Health']
# ['h01-Pz-171.jpg', 'Health']
# ['h01-Pz-175.jpg', 'Health']
# ['h01-Pz-176.jpg', 'Health']
# ['h01-Pz-174.jpg', 'Health']
# ['h01-Pz-179.jpg', 'Health']
# ['h01-Pz-178.jpg', 'Health']
# ['h01-Pz-177.jpg', 'Health']
# ['h01-Pz-180.jpg', 'Health']
# ['h01-Pz-181.jpg', 'Health']
# ['h01-Pz-182.jpg', 'Health']
# ['h01-Pz-183.jpg', 'Health']
# ['h01-Pz-184.jpg', 'Health']
# ['h01-Pz-185.jpg', 'Health']
# ['h01-Pz-187.jpg', 'Health']
# ['h01-Pz-188.jpg', 'Health']
# ['h01-Pz-189.jpg', 'Health']
# ['h01-Pz-186.jpg', 'Health']
# ['h01-Pz-190.jpg', 'Health']
# ['h01-Pz-191.jpg', 'Health']
# ['h01-Pz-192.jpg', 'Health']
# ['h01-Pz-193.jpg', 'Health']
# ['h01-Pz-195.jpg', 'Health']
# ['h01-Pz-194.jpg', 'Health']
# ['h01-Pz-198.jpg', 'Health']
# ['h01-Pz-196.jpg', 'Health']
# ['h01-Pz-197.jpg', 'Health']
# ['h01-Pz-200.jpg', 'Health']
# ['h01-Pz-199.jpg', 'Health']
# ['h01-Pz-201.jpg', 'Health']
# ['h01-Pz-204.jpg', 'Health']
# ['h01-Pz-203.jpg', 'Health']
# ['h01-Pz-202.jpg', 'Health']
# ['h01-Pz-205.jpg', 'Health']
# ['h01-Pz-207.jpg', 'Health']
# ['h01-Pz-206.jpg', 'Health']
# ['h01-Pz-208.jpg', 'Health']
# ['h01-Pz-209.jpg', 'Health']
# ['h02-Fz-0.jpg', 'Health']
# ['h01-Pz-210.jpg', 'Health']
# ['h02-Fz-2.jpg', 'Health']
# ['h02-Fz-1.jpg', 'Health']
# ['h02-Fz-3.jpg', 'Health']
# ['h02-Fz-6.jpg', 'Health']
# ['h02-Fz-5.jpg', 'Health']
# ['h02-Fz-4.jpg', 'Health']
# ['h02-Fz-9.jpg', 'Health']
# ['h02-Fz-8.jpg', 'Health']
# ['h02-Fz-7.jpg', 'Health']
# ['h02-Fz-11.jpg', 'Health']
# ['h02-Fz-10.jpg', 'Health']
# ['h02-Fz-12.jpg', 'Health']
# ['h02-Fz-16.jpg', 'Health']
# ['h02-Fz-13.jpg', 'Health']
# ['h02-Fz-15.jpg', 'Health']
# ['h02-Fz-14.jpg', 'Health']
# ['h02-Fz-17.jpg', 'Health']
# ['h02-Fz-19.jpg', 'Health']
# ['h02-Fz-18.jpg', 'Health']
# ['h02-Fz-21.jpg', 'Health']
# ['h02-Fz-20.jpg', 'Health']
# ['h02-Fz-22.jpg', 'Health']
# ['h02-Fz-23.jpg', 'Health']
# ['h02-Fz-24.jpg', 'Health']
# ['h02-Fz-25.jpg', 'Health']
# ['h02-Fz-27.jpg', 'Health']
# ['h02-Fz-28.jpg', 'Health']
# ['h02-Fz-26.jpg', 'Health']
# ['h02-Fz-30.jpg', 'Health']
# ['h02-Fz-29.jpg', 'Health']
# ['h02-Fz-32.jpg', 'Health']
# ['h02-Fz-31.jpg', 'Health']
# ['h02-Fz-33.jpg', 'Health']
# ['h02-Fz-34.jpg', 'Health']
# ['h02-Fz-35.jpg', 'Health']
# ['h02-Fz-37.jpg', 'Health']
# ['h02-Fz-36.jpg', 'Health']
# ['h02-Fz-38.jpg', 'Health']
# ['h02-Fz-39.jpg', 'Health']
# ['h02-Fz-41.jpg', 'Health']
# ['h02-Fz-40.jpg', 'Health']
# ['h02-Fz-43.jpg', 'Health']
# ['h02-Fz-42.jpg', 'Health']
# ['h02-Fz-44.jpg', 'Health']
# ['h02-Fz-45.jpg', 'Health']
# ['h02-Fz-46.jpg', 'Health']
# ['h02-Fz-47.jpg', 'Health']
# ['h02-Fz-49.jpg', 'Health']
# ['h02-Fz-48.jpg', 'Health']
# ['h02-Fz-50.jpg', 'Health']
# ['h02-Fz-51.jpg', 'Health']
# ['h02-Fz-52.jpg', 'Health']
# ['h02-Fz-54.jpg', 'Health']
# ['h02-Fz-53.jpg', 'Health']
# ['h02-Fz-58.jpg', 'Health']
# ['h02-Fz-55.jpg', 'Health']
# ['h02-Fz-57.jpg', 'Health']
# ['h02-Fz-56.jpg', 'Health']
# ['h02-Fz-59.jpg', 'Health']
# ['h02-Fz-60.jpg', 'Health']
# ['h02-Fz-61.jpg', 'Health']
# ['h02-Fz-63.jpg', 'Health']
# ['h02-Fz-62.jpg', 'Health']
# ['h02-Fz-64.jpg', 'Health']
# ['h02-Fz-65.jpg', 'Health']
# ['h02-Fz-66.jpg', 'Health']
# ['h02-Fz-68.jpg', 'Health']
# ['h02-Fz-67.jpg', 'Health']
# ['h02-Fz-69.jpg', 'Health']
# ['h02-Fz-70.jpg', 'Health']
# ['h02-Fz-71.jpg', 'Health']
# ['h02-Fz-72.jpg', 'Health']
# ['h02-Fz-74.jpg', 'Health']
# ['h02-Fz-73.jpg', 'Health']
# ['h02-Fz-75.jpg', 'Health']
# ['h02-Fz-76.jpg', 'Health']
# ['h02-Fz-78.jpg', 'Health']
# ['h02-Fz-77.jpg', 'Health']
# ['h02-Fz-80.jpg', 'Health']
# ['h02-Fz-79.jpg', 'Health']
# ['h02-Fz-81.jpg', 'Health']
# ['h02-Fz-82.jpg', 'Health']
# ['h02-Fz-84.jpg', 'Health']
# ['h02-Fz-83.jpg', 'Health']
# ['h02-Fz-85.jpg', 'Health']
# ['h02-Fz-86.jpg', 'Health']
# ['h02-Fz-88.jpg', 'Health']
# ['h02-Fz-87.jpg', 'Health']
# ['h02-Fz-89.jpg', 'Health']
# ['h02-Fz-91.jpg', 'Health']
# ['h02-Fz-90.jpg', 'Health']
# ['h02-Fz-93.jpg', 'Health']
# ['h02-Fz-94.jpg', 'Health']
# ['h02-Fz-92.jpg', 'Health']
# ['h02-Fz-96.jpg', 'Health']
# ['h02-Fz-95.jpg', 'Health']
# ['h02-Fz-97.jpg', 'Health']
# ['h02-Fz-98.jpg', 'Health']
# ['h02-Fz-101.jpg', 'Health']
# ['h02-Fz-99.jpg', 'Health']
# ['h02-Fz-100.jpg', 'Health']
# ['h02-Fz-103.jpg', 'Health']
# ['h02-Fz-104.jpg', 'Health']
# ['h02-Fz-105.jpg', 'Health']
# ['h02-Fz-102.jpg', 'Health']
# ['h02-Fz-108.jpg', 'Health']
# ['h02-Fz-106.jpg', 'Health']
# ['h02-Fz-107.jpg', 'Health']
# ['h02-Fz-111.jpg', 'Health']
# ['h02-Fz-109.jpg', 'Health']
# ['h02-Fz-110.jpg', 'Health']
# ['h02-Fz-114.jpg', 'Health']
# ['h02-Fz-113.jpg', 'Health']
# ['h02-Fz-112.jpg', 'Health']
# ['h02-Fz-117.jpg', 'Health']
# ['h02-Fz-115.jpg', 'Health']
# ['h02-Fz-116.jpg', 'Health']
# ['h02-Fz-119.jpg', 'Health']
# ['h02-Fz-118.jpg', 'Health']
# ['h02-Fz-120.jpg', 'Health']
# ['h02-Fz-121.jpg', 'Health']
# ['h02-Fz-123.jpg', 'Health']
# ['h02-Fz-124.jpg', 'Health']
# ['h02-Fz-122.jpg', 'Health']
# ['h02-Fz-127.jpg', 'Health']
# ['h02-Fz-126.jpg', 'Health']
# ['h02-Fz-125.jpg', 'Health']
# ['h02-Fz-129.jpg', 'Health']
# ['h02-Fz-130.jpg', 'Health']
# ['h02-Fz-128.jpg', 'Health']
# ['h02-Fz-131.jpg', 'Health']
# ['h02-Fz-134.jpg', 'Health']
# ['h02-Fz-132.jpg', 'Health']
# ['h02-Fz-133.jpg', 'Health']
# ['h02-Fz-136.jpg', 'Health']
# ['h02-Fz-135.jpg', 'Health']
# ['h02-Fz-137.jpg', 'Health']
# ['h02-Fz-138.jpg', 'Health']
# ['h02-Fz-140.jpg', 'Health']
# ['h02-Fz-139.jpg', 'Health']
# ['h02-Fz-142.jpg', 'Health']
# ['h02-Fz-144.jpg', 'Health']
# ['h02-Fz-141.jpg', 'Health']
# ['h02-Fz-143.jpg', 'Health']
# ['h02-Fz-147.jpg', 'Health']
# ['h02-Fz-146.jpg', 'Health']
# ['h02-Fz-145.jpg', 'Health']
# ['h02-Fz-150.jpg', 'Health']
# ['h02-Fz-149.jpg', 'Health']
# ['h02-Fz-148.jpg', 'Health']
# ['h02-Fz-153.jpg', 'Health']
# ['h02-Fz-151.jpg', 'Health']
# ['h02-Fz-152.jpg', 'Health']
# ['h02-Fz-155.jpg', 'Health']
# ['h02-Fz-154.jpg', 'Health']
# ['h02-Fz-156.jpg', 'Health']
# ['h02-Fz-157.jpg', 'Health']
# ['h02-Fz-158.jpg', 'Health']
# ['h02-Fz-161.jpg', 'Health']
# ['h02-Fz-160.jpg', 'Health']
# ['h02-Fz-159.jpg', 'Health']
# ['h02-Fz-162.jpg', 'Health']
# ['h02-Fz-163.jpg', 'Health']
# ['h02-Fz-164.jpg', 'Health']
# ['h02-Fz-165.jpg', 'Health']
# ['h02-Fz-166.jpg', 'Health']
# ['h02-Fz-168.jpg', 'Health']
# ['h02-Fz-167.jpg', 'Health']
# ['h02-Fz-171.jpg', 'Health']
# ['h02-Fz-169.jpg', 'Health']
# ['h02-Fz-170.jpg', 'Health']
# ['h02-Fz-172.jpg', 'Health']
# ['h02-Fz-173.jpg', 'Health']
# ['h02-Fz-174.jpg', 'Health']
# ['h02-Fz-175.jpg', 'Health']
# ['h02-Fz-176.jpg', 'Health']
# ['h02-Fz-178.jpg', 'Health']
# ['h02-Fz-177.jpg', 'Health']
# ['h02-Fz-180.jpg', 'Health']
# ['h02-Fz-179.jpg', 'Health']
# ['h02-Fz-182.jpg', 'Health']
# ['h02-Fz-181.jpg', 'Health']
# ['h02-Fz-183.jpg', 'Health']
# ['h02-Fz-185.jpg', 'Health']
# ['h02-Fz-184.jpg', 'Health']
# ['h02-Fz-186.jpg', 'Health']
# ['h02-Fz-187.jpg', 'Health']
# ['h02-Fz-189.jpg', 'Health']
# ['h02-Fz-188.jpg', 'Health']
# ['h02-Fz-190.jpg', 'Health']
# ['h02-Fz-193.jpg', 'Health']
# ['h02-Fz-191.jpg', 'Health']
# ['h02-Fz-192.jpg', 'Health']
# ['h02-Fz-194.jpg', 'Health']
# ['h02-Fz-196.jpg', 'Health']
# ['h02-Fz-195.jpg', 'Health']
# ['h02-Fz-199.jpg', 'Health']
# ['h02-Fz-197.jpg', 'Health']
# ['h02-Fz-198.jpg', 'Health']
# ['h02-Fz-201.jpg', 'Health']
# ['h02-Fz-202.jpg', 'Health']
# ['h02-Fz-200.jpg', 'Health']
# ['h02-Fz-203.jpg', 'Health']
# ['h02-Fz-204.jpg', 'Health']
# ['h02-Fz-205.jpg', 'Health']
# ['h02-Fz-206.jpg', 'Health']
# ['h02-Fz-208.jpg', 'Health']
# ['h02-Fz-207.jpg', 'Health']
# ['h02-Fz-209.jpg', 'Health']
# ['h02-Cz-0.jpg', 'Health']
# ['h02-Fz-210.jpg', 'Health']
# ['h02-Cz-1.jpg', 'Health']
# ['h02-Cz-4.jpg', 'Health']
# ['h02-Cz-3.jpg', 'Health']
# ['h02-Cz-2.jpg', 'Health']
# ['h02-Cz-6.jpg', 'Health']
# ['h02-Cz-5.jpg', 'Health']
# ['h02-Cz-7.jpg', 'Health']
# ['h02-Cz-9.jpg', 'Health']
# ['h02-Cz-10.jpg', 'Health']
# ['h02-Cz-11.jpg', 'Health']
# ['h02-Cz-8.jpg', 'Health']
# ['h02-Cz-14.jpg', 'Health']
# ['h02-Cz-13.jpg', 'Health']
# ['h02-Cz-12.jpg', 'Health']
# ['h02-Cz-17.jpg', 'Health']
# ['h02-Cz-15.jpg', 'Health']
# ['h02-Cz-16.jpg', 'Health']
# ['h02-Cz-19.jpg', 'Health']
# ['h02-Cz-18.jpg', 'Health']
# ['h02-Cz-20.jpg', 'Health']
# ['h02-Cz-23.jpg', 'Health']
# ['h02-Cz-22.jpg', 'Health']
# ['h02-Cz-21.jpg', 'Health']
# ['h02-Cz-27.jpg', 'Health']
# ['h02-Cz-26.jpg', 'Health']
# ['h02-Cz-25.jpg', 'Health']
# ['h02-Cz-24.jpg', 'Health']
# ['h02-Cz-30.jpg', 'Health']
# ['h02-Cz-29.jpg', 'Health']
# ['h02-Cz-28.jpg', 'Health']
# ['h02-Cz-32.jpg', 'Health']
# ['h02-Cz-31.jpg', 'Health']
# ['h02-Cz-33.jpg', 'Health']
# ['h02-Cz-34.jpg', 'Health']
# ['h02-Cz-35.jpg', 'Health']
# ['h02-Cz-36.jpg', 'Health']
# ['h02-Cz-38.jpg', 'Health']
# ['h02-Cz-39.jpg', 'Health']
# ['h02-Cz-37.jpg', 'Health']
# ['h02-Cz-41.jpg', 'Health']
# ['h02-Cz-40.jpg', 'Health']
# ['h02-Cz-42.jpg', 'Health']
# ['h02-Cz-45.jpg', 'Health']
# ['h02-Cz-44.jpg', 'Health']
# ['h02-Cz-46.jpg', 'Health']
# ['h02-Cz-43.jpg', 'Health']
# ['h02-Cz-47.jpg', 'Health']
